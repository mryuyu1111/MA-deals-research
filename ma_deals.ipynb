# %%
import csv
import pandas as pd
import numpy as np
import calendar
import matplotlib.pyplot as plt
from __future__ import division
from datetime import datetime, timedelta
import statsmodels.api as sm
import holidays
# Out:
# C:\Users\kcheng\AppData\Local\Continuum\anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Read the 1990 M&A deals from file and generate a csv file that pull EPS data from bloomberg

# %% [markdown]
# #### Extracted one thousand nine hundread and ninty M&A deals based on below criteria
# - Deal Status: Pending, Completed, Terminated
# - Dates: 1/1/2010 to 12/12/2017
# - Deal Type: M&A
# - Exchange: Include: United States, Apply to Target
# - Payment date: Cash, Stock, Cash & Stock, Cash or Stock
# - Public/Private: Public, Apply to Target
# - Deal Size: 400 million dollars

# %%
base_dir = './/'

def get_ma_cash_deals(filename):
    ma_deals = pd.read_csv(filename, header=0)

    ma_deals = ma_deals[ma_deals['Payment Type'] == 'Cash']
    print 'Cash deals: ' + str(len(ma_deals))
    ma_deals = ma_deals[ma_deals['Cash Terms'].notnull()]
    print 'Cash Terms excluded NA deals: ' + str(len(ma_deals))
    ma_deals = ma_deals[~ma_deals['Cash Terms'].str.contains('Mln')]
    print 'Cash Terms in per share deals: ' + str(len(ma_deals))
    ma_deals = ma_deals[ma_deals['Target Ticker'].notnull()]
    print 'Target Ticker not null deals: ' + str(len(ma_deals))
    print 'Unique target ticker count: ' + str(len(ma_deals['Target Ticker'].unique()))
    print 'Total Cash deals count at the end: ' + str(len(ma_deals))
    return ma_deals
ma_deals = get_ma_cash_deals(base_dir + 'ma_deals_sh.csv')
ma_deals
# Out:
# Cash deals: 1313
# Cash Terms excluded NA deals: 1312
# Cash Terms in per share deals: 1235
# Target Ticker not null deals: 1235
# Unique target ticker count: 1139
# Total Cash deals count at the end: 1235
#       Action ID Announce Date Target Ticker  \
# 0      69224411     9/27/2012         ZZ US
# 2     112314918     11/6/2015       ZSPH US
# 3     125179220      5/5/2016       ZPIN US
# 4      81900649     9/26/2013       ZOLT US
# 5      62404789     3/12/2012       ZOLL US
# 6      43195085     2/18/2010        ZNT US
# 7     140287996     2/13/2017       ZLTQ US
# 8      87551829     2/19/2014        ZLC US
# 9      56303521     7/20/2011         ZL CN
# 10     72579414      1/2/2013        ZIP US
# 12     48043400      9/7/2010       ZGEN US
# 13    105214134      4/8/2015        ZEP US
# 14    124386594     1/19/2017         ZC FP
# 15    109424566      7/9/2015         YY US
# 16    114213333    10/16/2015       YOKU US
# 19    139414367     1/30/2017       XXIA US
# 20    146250928     5/30/2017       XTLY US
# 22     63236178     4/10/2012       XRIT US
# 23    109081535      7/1/2015       XOOM US
# 25    143625705     4/10/2017       XCRA US
# 26     49329529     11/1/2010        XCO US
# 27    115671578     10/4/2015        XCH LN
# 29    106231939     4/30/2015         WX US
# 31    128451851      7/7/2016       WWAV US
# 34     93385053      7/7/2014        WTF AU
# 36    134894105      5/9/2017       WSTC US
# 37     48751436     10/6/2010        WSM LN
# 38     74260946     2/21/2013      WSHLY US
# 39     65203199      6/7/2012        WSH LN
# 44    138420760      1/9/2017       WOOF US
# ...         ...           ...           ...
# 1917   72738506      1/7/2013   1236053D US
# 1919   78469555     6/18/2013       1230 HK
# 1922   66515401     7/17/2012       1192 HK
# 1925   49148893    10/25/2010   1074528D US
# 1927   63994926      5/2/2012   1073675D US
# 1928  141628246      3/6/2017        107 HK
# 1929   76402000     4/25/2013   1052394D US
# 1930  149180712     9/22/2017       1030 HK
# 1934   63860193     4/30/2012   0991739D US
# 1935   58664215    10/24/2011   0967702D US
# 1936   73544130     1/31/2013   0966576D US
# 1937   73199288     1/18/2013   0965087D US
# 1939   73114820     1/16/2013   0955035D CN
# 1940   46394997     6/30/2010   0954772D US
# 1941   69182150     9/26/2012   0948669D US
# 1943   58080373     9/30/2011   0947035D CN
# 1944   54468887     5/12/2011   0905737D HK
# 1945   55440074     6/16/2011   0882565D US
# 1947   48675578     10/4/2010   0852980D US
# 1948   73781769      2/6/2013   0852651D US
# 1949   58848889    10/31/2011   0851201D CN
# 1950   69794386    10/15/2012   0848680D US
# 1957   55398169     6/15/2011   0759047D CN
# 1958   56318401     7/20/2011   0700161D US
# 1960   48684806     10/4/2010   0625947D CN
# 1967   45150022      5/7/2010   0313624D US
# 1970   53392170      4/4/2011   0203524D US
# 1971   43424164     2/28/2010   0202445Q US
# 1972   43685192     2/25/2010   0174196D CN
# 1974   56182378     7/15/2011   0167866D US
#
#                                Target Name Acquirer Ticker  \
# 0                               Sealy Corp          TPX US
# 2                            ZS Pharma Inc          AZN LN
# 3                              Zhaopin Ltd             NaN
# 4                           Zoltek Cos Inc         3402 JP
# 5                        Zoll Medical Corp         3407 JP
# 6           Zenith National Insurance Corp          FFH CN
# 7                    Zeltiq Aesthetics Inc          AGN US
# 8                                Zale Corp          SIG US
# 9             Microsemi Semiconductor Corp         MSCC US
# 10                              Zipcar Inc          CAR US
# 12                        ZymoGenetics Inc          BMY US
# 13                                 Zep Inc      161147Z US
# 14                        Zodiac Aerospace          SAF FP
# 15                                  YY Inc             NaN
# 16                         Youku Tudou Inc         BABA US
# 19                                    Ixia         KEYS US
# 20                             Xactly Corp      389272Z US
# 22                              X-Rite Inc          DHR US
# 23                               Xoom Corp         PYPL US
# 25                             Xcerra Corp     1334073D CH
# 26                      EXCO Resources Inc             NaN
# 27                           Xchanging Ltd          CSC US
# 29              WuXi PharmaTech Cayman Inc             NaN
# 31                  WhiteWave Foods Co/The           BN FP
# 34                  Wotif.com Holdings Ltd         EXPE US
# 36                               West Corp          APO US
# 37                 Wellstream Holdings Ltd           GE US
# 38                        WSP Holdings Ltd     0111135D US
# 39                           WSP Group Ltd          WSP CN
# 44                                 VCA Inc        4614Z US
# ...                                    ...             ...
# 1917                   EnergySolutions Inc      769664Z US
# 1919    Yashili International Holdings Ltd         2319 HK
# 1922        Titan Petrochemicals Group Ltd       IJAIMZ CH
# 1925                         CommScope Inc             NaN
# 1927                  Charming Shoppes Inc         ASNA US
# 1928             Sichuan Expressway Co Ltd       SCDHCZ CH
# 1929                  MPG Office Trust Inc          BPO CN
# 1930  Future Land Development Holdings Ltd     1547348D KY
# 1934                         Gen-Probe Inc         HOLX US
# %% [markdown]
# ##### Eliminate the fake break deals. Manually change the below 4 tickers plus 6753 JP

# %%
duplicated_cash_ma_deals = ma_deals[ma_deals['Target Ticker'].duplicated()]
print len(duplicated_cash_ma_deals['Target Ticker'].unique())
tt_count = ma_deals.groupby(['Target Ticker']).size().reset_index(name='count')
dtt_deals = tt_count[tt_count['count'] > 1]
print 'Duplicated target ticker count: %d' % len(dtt_deals)
dtt_deals[dtt_deals['count'] > 2]
# Out:
# 96
# Duplicated target ticker count: 96
# Empty DataFrame
# Columns: [Target Ticker, count]
# Index: []

# %%
ma_deals = get_ma_cash_deals(base_dir + 'ma_deals_sh_filtered.csv')

tt_count = ma_deals.groupby(['Target Ticker']).size().reset_index(name='count')
dtt_deals_tickers = tt_count[tt_count['count'] > 1]
# Out:
# Cash deals: 1312
# Cash Terms excluded NA deals: 1311
# Cash Terms in per share deals: 1234
# Target Ticker not null deals: 1234
# Unique target ticker count: 1139
# Total Cash deals count at the end: 1234

# %%
duplicated_cash_ma_deals = ma_deals[ma_deals['Target Ticker'].duplicated(keep=False)]
len(duplicated_cash_ma_deals['Target Ticker'].unique())
# Out:
# 95

# %%
unique_cash_ma_deals = ma_deals[~ma_deals['Target Ticker'].duplicated(keep=False)]
len(unique_cash_ma_deals)
# Out:
# 1044

# %%
unique_cash_ma_deals.to_csv('unique_cash_ma_deals.csv', index=False)
ter_unique_targets_count = len(unique_cash_ma_deals[unique_cash_ma_deals['Deal Status'] == 'Terminated'])
print 'Number of unique Target name got terminated: ' + str(ter_unique_targets_count)
# Out:
# Number of unique Target name got terminated: 97

# %%
duplicated_cash_ma_deals = duplicated_cash_ma_deals.sort_values(by=['Target Ticker', 'Announce Date'], ascending=[True, False])

# %%
duplicated_cash_ma_deals.to_csv('duplicated.csv', index=False)

# %%
ter_duplicated_targets_count = len(duplicated_cash_ma_deals[duplicated_cash_ma_deals['Deal Status'] == 'Terminated'])
print 'Number of Duplicated Target name got terminated: ' + str(ter_duplicated_targets_count)
# Out:
# Number of Duplicated Target name got terminated: 88

# %%
def is_overlapping(a_s_date, a_e_date, b_s_date, b_e_date):
    a_s_date = datetime.strptime(a_s_date, '%m/%d/%Y')
    a_e_date = datetime.strptime(a_e_date, '%m/%d/%Y')
    b_s_date = datetime.strptime(b_s_date, '%m/%d/%Y')
    b_e_date = datetime.strptime(b_e_date, '%m/%d/%Y')
    if b_s_date <= a_e_date and a_e_date <= b_e_date:
        return True
    if a_s_date <= b_e_date and b_e_date <= a_s_date:
        return True
    if b_s_date <= a_s_date and a_s_date <= b_e_date:
        return True
    if a_s_date <= b_s_date and b_s_date <= a_e_date:
        return True
    return False

def get_start_close_date_price_status(a_s_date, a_e_date, b_s_date, b_e_date, a_cash_term, b_cash_term, a_status, b_status):
    s_date = min(a_s_date, b_s_date)
    e_date = max(a_e_date, b_e_date)
    cash_term = max(a_cash_term, b_cash_term)
    if a_status == b_status:
        status = a_status
    else:
        # may be pending
        if a_status == 'Pending' or a_status == 'Completed':
            status = a_status
        else:
            status = b_status
    return s_date, e_date, cash_term, status

def add_180_days(date):
    try:
        date = datetime.strptime(date.strip(), '%m/%d/%Y')
    except:
#         if date <= datetime.today():
        date = datetime.today() + timedelta(days=180)
    return datetime.strftime(date, '%m/%d/%Y')
    
def filter_fake_break_deals(duplicated_cash_ma_deals):
    filtered_deals = []
    count = 0
    fir_row = None
    sec_row = None           
    for i, row in duplicated_cash_ma_deals.iterrows():
        count += 1
        if count % 2 == 0:
            sec_row = row
            a_s_date, a_e_date, b_s_date, b_e_date = fir_row['Announce Date'], fir_row['Completion/Termination Date'], sec_row['Announce Date'], sec_row['Completion/Termination Date']
            a_e_date = add_180_days(a_e_date)
            b_e_date = add_180_days(b_e_date)
            if is_overlapping(a_s_date, a_e_date, b_s_date, b_e_date):
                # when there is an overlapping period in 2 deals and both have same status,
                # i.e. both completed or terminated, then count as one deal with the longest 
                # period
                s_date, e_date, cash_term, status = get_start_close_date_price_status(
                                    a_s_date, a_e_date, b_s_date, b_e_date,
                                    fir_row['Cash Terms'], sec_row['Cash Terms'],
                                    fir_row['Deal Status'], sec_row['Deal Status'])
                fir_row['Announce Date'] = s_date
                fir_row['Completion/Termination Date'] = e_date
                fir_row['Cash Terms'] = cash_term
                fir_row['Deal Status'] = status
                filtered_deals.append(fir_row.to_frame().transpose())
            else:
                # add both rows to the new df
                filtered_deals.append(fir_row.to_frame().transpose())
                filtered_deals.append(sec_row.to_frame().transpose())
        else:
            fir_row = row
        
    return pd.concat(filtered_deals)

filtered_deals = filter_fake_break_deals(duplicated_cash_ma_deals)

# %%
filtered_deals.to_csv('filtered_deals.csv', index=False)

# %%
# ma_deals = pd.concat([unique_cash_ma_deals, duplicated_cash_ma_deals])
ma_deals = pd.concat([unique_cash_ma_deals, filtered_deals])
# (duplicated_cash_ma_deals.groupby(["Target Ticker", "Announce Date"])['Action ID'].count() > 1)

# %%
len(filtered_deals[filtered_deals['Deal Status']=='Pending'])
# Out:
# 8

# %%
len(ma_deals)
# Out:
# 1174

# %%
import holidays

def get_pre_holiday_day(date):
    day_dict = {0:'Mon', 1:'Tues', 2:'Wed', 3:'Thur', 4:'Fri', 5:'Sat', 6:'Sun'}
    us_holidays = holidays.UnitedStates()
#     if date != np.datetime64('NaT'):
    if isinstance(date, str):
        datetime_date = datetime.strptime(date, '%m/%d/%Y')
        day_num = datetime_date.weekday()
        if us_holidays.get(datetime_date):
            date = datetime_date - timedelta(days=1)
            date = datetime.strftime(date, '%m/%d/%Y')
            return get_pre_holiday_day(date)
        if day_num >= 5:
            date = datetime_date - timedelta(days=(day_num - 4))
            date = datetime.strftime(date, '%m/%d/%Y')
            return get_pre_holiday_day(date)
        date = date.split('/')
        date = date[0].lstrip('0') + '/' + date[1].lstrip('0') + '/' + date[2]
        return date
    else:
        return date

# %%
import holidays
day_dict = {0:'Mon', 1:'Tues', 2:'Wed', 3:'Thur', 4:'Fri', 5:'Sat', 6:'Sun'}
us_holidays = holidays.UnitedStates()
ma_deals_holidays = []
# for date in ma_deals_eps_pull['Date F'].values:
for date in res['Date F'].values:
    if date != np.datetime64('NaT'):
        datetime_date = date.astype('M8[D]').astype('O')
        day_num = datetime_date.weekday()
        if day_num >= 5:
            print 'weekend ' + str(date) + ' ' + day_dict[day_num]
            ma_deals_holidays.append(str(date))
        else:
            if us_holidays.get(datetime_date):
                print 'US holiday ' + str(date) + ' ' + day_dict[day_num]
                ma_deals_holidays.append(str(date))
print len(ma_deals_holidays)
# Out:
# 0

# %%
print len(ma_deals[ma_deals['Deal Status'] == 'Completed'])
print len(ma_deals[ma_deals['Deal Status'] == 'Terminated'])
print len(ma_deals[ma_deals['Deal Status'] == 'Pending'])
# Out:
# 978
# 136
# 60

# %%
def avg_duration(df, deal_status):
    sum_duration = (df['Completion/Termination Date'].apply(lambda date : datetime.strptime(date, '%m/%d/%Y')) - df['Announce Date'].apply(lambda date : datetime.strptime(date, '%m/%d/%Y'))).astype('timedelta64[D]').sum()
    avg_days = sum_duration / len(df)
    print 'Number of deals: %s. Average number of days spent on %s deals: %s' % (len(df), deal_status, str(avg_days))
    return avg_days

completed_deals = ma_deals[ma_deals['Deal Status'] == 'Completed']
completed_avg_days = avg_duration(completed_deals, 'Completed')
# for industry in completed_deals['Target Industry Sector'].unique():
#     deals = completed_deals[completed_deals['Target Industry Sector'] == industry]
#     avg_duration(deals, industry)
# print
terminated_deals = ma_deals[ma_deals['Deal Status'] == 'Terminated']
terminated_avg_days = avg_duration(terminated_deals, 'Terminated')
# for industry in terminated_deals['Target Industry Sector'].unique():
#     deals = terminated_deals[terminated_deals['Target Industry Sector'] == industry]
#     avg_duration(deals, industry)
# print
# for industry in ma_deals['Target Industry Sector'].unique():
#     deals = ma_deals[ma_deals['Target Industry Sector'] == industry]
#     print industry + ': ' + str(len(deals))
# Out:
# Number of deals: 978. Average number of days spent on Completed deals: 132.568507157
# Number of deals: 136. Average number of days spent on Terminated deals: 131.727941176

# %%
target_tickers = ma_deals['Target Ticker']
print 'Number of NaN target ticker(s): %s' % pd.isnull(target_tickers).sum()

def write_BDS_csv(filename, tickers):
    with open(filename, 'wb') as csvfile:
        writer = csv.writer(csvfile, quoting=csv.QUOTE_NONE, escapechar ='\\')
        for ticker in tickers.dropna():
            writer.writerow([ticker])
            writer.writerow([r'=BDS("%s Equity","EARN_ANN_DT_TIME_HIST_WITH_EPS")' % ticker])
            for i in range(150):
                writer.writerow('')

    with open(filename, 'rb') as f:
        data = f.read()
    with open(filename, 'wb') as g:
        g.write(data.replace('\\"', '\"').replace('Equity\"\\', 'Equity\"'))

write_BDS_csv(base_dir + '1990_ma_deals_eps_hist.csv', target_tickers)
# Out:
# Number of NaN target ticker(s): 0

# %% [markdown]
# ### After pulling EPS from Bloomberg, analyze the stock price movement during earnings announcement throughout the period between announce date and completion/termination date

# %% [markdown]
# #### change the header name, drop the empty lines (NA), format the date to datetime object

# %%
def load_df(filename, columns, format_date=False, reindex=True, pre_holiday=False):
    df = pd.read_csv(filename, header=None)
    df.columns = columns
    df = df.dropna(axis=0, how='all')
    if pre_holiday:
        df['Date'] = df['Date'].apply(lambda date : get_pre_holiday_day(date))
    if format_date:
        df['Date F'] = pd.to_datetime(df['Date'], errors='coerce')
    df = df.reset_index(drop=reindex)
    return df

def cal_eps_diff(df):
    df['Est EPS diff'] = (df['EPS'] - df['Est EPS'])
#     df['Peer EPS diff'] = (df['EPS'] - df['Peer EPS'])
    df['Est EPS diff percentage'] = df['Est EPS diff'] / abs(df['Est EPS'])
#     df['Peer EPS diff percentage'] = df['Peer EPS diff'] / abs(df['EPS'])
    

ma_deals_eps_pull = load_df(base_dir + '1990_ma_deals_eps_pull.csv', 
                                 ['Quarter', 'Date', 'Time', 'Unknown', 'EPS', 'Est EPS'],
                                format_date=True, pre_holiday=True)
cal_eps_diff(ma_deals_eps_pull)
ma_deals_eps_pull
# Out:
#        Quarter        Date     Time   Unknown       EPS  Est EPS     Date F  \
# 0        ZZ US         NaN      NaN       NaN       NaN      NaN        NaT
# 1      2012:Q4   1/23/2013    16:01    0.0086     0.040      NaN 2013-01-23
# 2      2012:Q3   9/27/2012     7:05    0.0025     0.000      NaN 2012-09-27
# 3      2012:Q2   6/26/2012    16:01    0.0408     0.020      NaN 2012-06-26
# 4      2012:Q1   3/27/2012    16:01    0.0154     0.020      NaN 2012-03-27
# 5      2011:Q4   1/18/2012    16:01   -0.1403    -0.140      NaN 2012-01-18
# 6      2011:Q3   9/27/2011    16:02    0.0400     0.040      NaN 2011-09-27
# 7      2011:Q2   6/28/2011    16:01    0.0100     0.020      NaN 2011-06-28
# 8      2011:Q1   3/29/2011    16:14    0.0010     0.000      NaN 2011-03-29
# 9      2010:Q4   1/13/2011    16:01    0.0305     0.030      NaN 2011-01-13
# 10     2010:Q3   9/28/2010    16:01    0.1026     0.080      NaN 2010-09-28
# 11     2010:Q2   6/29/2010    16:01    0.0388     0.020      NaN 2010-06-29
# 12     2010:Q1   3/30/2010    16:01    0.0426     0.030      NaN 2010-03-30
# 13     2009:Q4   1/13/2010    16:01    0.0229     0.020      NaN 2010-01-13
# 14     2009:Q3   9/29/2009    16:01    0.0506     0.050      NaN 2009-09-29
# 15     2009:Q2   6/30/2009    16:01    0.2202     0.070      NaN 2009-06-30
# 16     2009:Q1   3/31/2009    16:01    0.0390     0.040     0.04 2009-03-31
# 17     2008:Q4   1/15/2009    16:01   -0.2160    -0.130      NaN 2009-01-15
# 18     2008:Q3   10/7/2008    16:01    0.1600     0.160      NaN 2008-10-07
# 19     2008:Q2    7/8/2008    16:02    0.0900     0.100      NaN 2008-07-08
# 20     2008:Q1    4/8/2008    16:01    0.1700     0.170      NaN 2008-04-08
# 21     2007:Q4   1/31/2008    16:01    0.1900     0.190      NaN 2008-01-31
# 22     2007:Q3   10/4/2007  Aft-mkt    0.2200     0.220      NaN 2007-10-04
# 23     2007:Q2   7/10/2007  Aft-mkt    0.1600     0.170      NaN 2007-07-10
# 24     2007:Q1    4/4/2007  Aft-mkt    0.2600     0.260      NaN 2007-04-04
# 25     2006:Q4   2/20/2007  Aft-mkt    0.2600     0.220      NaN 2007-02-20
# 26     2006:Q3  10/11/2006  Aft-mkt    0.3300     0.304      NaN 2006-10-11
# 27     2006:Q2   7/12/2006      NaN    0.3800     0.250      NaN 2006-07-12
# 28     2006:Q1   5/17/2006      NaN    0.3000     0.304      NaN 2006-05-17
# 29     2005:Q4   2/27/2006      NaN       NaN     0.000      NaN 2006-02-27
# ...        ...         ...      ...       ...       ...      ...        ...
# 83539   2003:A   4/27/2004      NaN  601.5221   544.000      NaN 2004-04-27
# 83540  2003:C4   2/19/2004      NaN       NaN       NaN      NaN 2004-02-19
# 83541  2003:C3  11/14/2003      NaN       NaN       NaN      NaN 2003-11-14
# 83542  2003:Q3  10/29/2003      NaN       NaN       NaN      NaN 2003-10-29
# 83543  2003:C2   8/14/2003      NaN       NaN       NaN      NaN 2003-08-14
# 83544  2003:Q2   8/14/2003      NaN       NaN       NaN      NaN 2003-08-14
# 83545  2003:C1   5/15/2003      NaN       NaN       NaN      NaN 2003-05-15
# 83546  2003:Q1   5/15/2003      NaN       NaN       NaN      NaN 2003-05-15
# 83547   2002:A   4/30/2003      NaN  658.0670   468.000      NaN 2003-04-30
# 83548  2002:C4   2/28/2003      NaN       NaN   492.000      NaN 2003-02-28
# 83549  2002:C3  11/14/2002      NaN       NaN       NaN      NaN 2002-11-14
# 83550  2002:Q3  11/14/2002      NaN       NaN       NaN      NaN 2002-11-14
# 83551  2002:C2   8/14/2002      NaN       NaN       NaN      NaN 2002-08-14
# 83552  2002:Q2   8/14/2002      NaN       NaN       NaN      NaN 2002-08-14
# 83553  2002:C1   5/15/2002      NaN       NaN       NaN      NaN 2002-05-15
# 83554  2002:Q1   5/15/2002      NaN       NaN       NaN      NaN 2002-05-15
# 83555   2001:A   4/30/2002      NaN       NaN   256.000      NaN 2002-04-30
# 83556  2001:C4    3/8/2002      NaN       NaN       NaN      NaN 2002-03-08
# 83557  2001:C3  11/14/2001      NaN       NaN       NaN      NaN 2001-11-14
# 83558  2001:C2   8/14/2001      NaN       NaN       NaN      NaN 2001-08-14
# 83559  2001:C1   5/15/2001      NaN       NaN       NaN      NaN 2001-05-15
# 83560   2000:A   4/30/2001      NaN       NaN   517.000      NaN 2001-04-30
# 83561  2000:C4    3/5/2001      NaN       NaN   477.000      NaN 2001-03-05
# 83562  2000:C3  11/14/2000      NaN       NaN       NaN      NaN 2000-11-14
# 83563  2000:C2   8/14/2000      NaN       NaN       NaN      NaN 2000-08-14
# 83564  2000:C1   5/15/2000      NaN       NaN       NaN      NaN 2000-05-15
# 83565   1999:A   4/28/2000      NaN       NaN  1001.000      NaN 2000-04-28
# 83566  1999:C4   3/17/2000      NaN       NaN       NaN      NaN 2000-03-17
# 83567  1999:C2   8/16/1999      NaN       NaN       NaN      NaN 1999-08-16
# 83568  1998:C4   3/26/1999      NaN       NaN       NaN      NaN 1999-03-26
#
#        Est EPS diff  Est EPS diff percentage
# 0               NaN                      NaN
# 1               NaN                      NaN
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
# 5               NaN                      NaN
# 6               NaN                      NaN
# 7               NaN                      NaN
# 8               NaN                      NaN
# 9               NaN                      NaN
# 10              NaN                      NaN
# 11              NaN                      NaN
# 12              NaN                      NaN
# 13              NaN                      NaN
# 14              NaN                      NaN
# 15              NaN                      NaN
# 16              0.0                      0.0
# 17              NaN                      NaN
# 18              NaN                      NaN
# 19              NaN                      NaN
# 20              NaN                      NaN
# 21              NaN                      NaN
# 22              NaN                      NaN
# 23              NaN                      NaN
# 24              NaN                      NaN
# 25              NaN                      NaN
# 26              NaN                      NaN
# 27              NaN                      NaN
# 28              NaN                      NaN
# 29              NaN                      NaN
# ...             ...                      ...
# 83539           NaN                      NaN
# 83540           NaN                      NaN
# 83541           NaN                      NaN
# 83542           NaN                      NaN
# 83543           NaN                      NaN
# 83544           NaN                      NaN
# 83545           NaN                      NaN
# 83546           NaN                      NaN
# 83547           NaN                      NaN
# 83548           NaN                      NaN
# 83549           NaN                      NaN
# 83550           NaN                      NaN
# 83551           NaN                      NaN
# 83552           NaN                      NaN
# 83553           NaN                      NaN
# 83554           NaN                      NaN
# 83555           NaN                      NaN
# 83556           NaN                      NaN
# 83557           NaN                      NaN
# 83558           NaN                      NaN
# 83559           NaN                      NaN
# 83560           NaN                      NaN
# 83561           NaN                      NaN
# 83562           NaN                      NaN
# 83563           NaN                      NaN
# 83564           NaN                      NaN
# 83565           NaN                      NaN
# 83566           NaN                      NaN
# 83567           NaN                      NaN
# 83568           NaN                      NaN
#
# [83569 rows x 9 columns]

# %%
def load_ticker_dict(df, index_col, first_col):
    ticker_index_list = df[df[index_col].isnull()].index
    ticker_price_dict = dict()
    for i in range(len(ticker_index_list)):
        start_index = ticker_index_list[i]+1
        ticker = df[first_col][ticker_index_list[i]]
        if i == len(ticker_index_list) - 1:
            end_index = len(df)
        else:
            end_index = ticker_index_list[i+1]
        ticker_price_dict[ticker] = df[start_index:end_index]
    return ticker_price_dict

ticker_dict = load_ticker_dict(ma_deals_eps_pull, 'Date', 'Quarter')
ticker_dict['ZPIN US']
# Out:
#     Quarter        Date   Time  Unknown   EPS  Est EPS     Date F  \
# 55  2017:Q4   8/15/2017  19:00     1.02   NaN      NaN 2017-08-15
# 56  2017:Q3   5/22/2017  18:00     0.84   NaN      NaN 2017-05-22
# 57  2017:Q2   2/17/2017  16:50    -0.08   NaN      NaN 2017-02-17
# 58  2017:Q1  11/23/2016  17:00     1.42   NaN      NaN 2016-11-23
# 59  2016:Q4   8/19/2016  18:30     1.56  3.20    1.070 2016-08-19
# 60  2016:Q3   5/23/2016  16:40     1.08  0.96    1.270 2016-05-23
# 61  2016:Q2   2/24/2016  16:40     1.08  1.16    1.357 2016-02-24
# 62  2016:Q1  11/18/2015  17:00     1.24  2.64    1.337 2015-11-18
# 63  2015:Q4   8/18/2015  17:55     1.28  1.32    1.287 2015-08-18
# 64  2015:Q3   5/26/2015  17:55     1.02  0.57      NaN 2015-05-26
# 65  2015:Q2   2/13/2015  16:55     1.10  1.22    1.360 2015-02-13
# 66  2015:Q1  11/12/2014  18:00     1.06  1.22    1.117 2014-11-12
# 67  2014:Q4   8/19/2014  18:00      NaN  1.26    1.015 2014-08-19
#
#     Est EPS diff  Est EPS diff percentage
# 55           NaN                      NaN
# 56           NaN                      NaN
# 57           NaN                      NaN
# 58           NaN                      NaN
# 59         2.130                 1.990654
# 60        -0.310                -0.244094
# 61        -0.197                -0.145173
# 62         1.303                 0.974570
# 63         0.033                 0.025641
# 64           NaN                      NaN
# 65        -0.140                -0.102941
# 66         0.103                 0.092211
# 67         0.245                 0.241379

# %% [markdown]
# #### For each Action ID (deal), extract the EPS between announcement date and completed/termination date. Some deal has no EPS info retrieved from Bloomberg because it's turned private.

# %%
today_date = datetime.now()
actionid_eps_dict = dict()
for index, row in ma_deals.iterrows():
    deal_status = row['Deal Status']
    ann_date = datetime.strptime(row['Announce Date'], '%m/%d/%Y')
    try:
        end_date = datetime.strptime(row['Completion/Termination Date'].strip(), '%m/%d/%Y')
    except:
        end_date = today_date
    if deal_status == 'Pending':
        if end_date <= today_date:
            end_date += timedelta(days=180)
       
    ticker = row['Target Ticker']
    if not isinstance(ticker, str):  # some target tickers are missing
        continue
    actionid = row['Action ID']
    ticker_eps_df = ticker_dict[ticker]
    ticker_eps_df = ticker_eps_df.loc[ticker_eps_df['Date F'] > ann_date].loc[ticker_eps_df['Date F'] < end_date]
    actionid_eps_dict[actionid] = ticker_eps_df

# %% [markdown]
# #### Create csv file that has the BHD bloomberg add-in function generated to pull historical prices for each ticker

# %%
today_date = datetime.now()
ticker_date_dict = dict()
for t in target_tickers.dropna().unique():
    df = ma_deals.loc[ma_deals['Target Ticker'] == t]
    ann_date = min([datetime.strptime(date, '%m/%d/%Y') for date in df['Announce Date'].values])
    end_date = max([datetime.strptime(date, '%m/%d/%Y') if len(date.strip()) != 0 else today_date for date in df['Completion/Termination Date'].values])
    if end_date > today_date:
        end_date = today_date
    if t not in ticker_date_dict.keys():
        ticker_date_dict[t] = [ann_date, end_date]
#     if ann_date == end_date:
#         print t, end_date
print len(ticker_date_dict)
# Out:
# 1139

# %%
with open(base_dir + '1990_ma_deals_BHD_price.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile, quoting=csv.QUOTE_NONE, escapechar ='\\')
    for ticker in target_tickers.dropna():
        writer.writerow([ticker])
        # give some buffer for the weekend
        ann_date = min(ticker_date_dict[ticker]) - timedelta(days=10)
        end_date = max(ticker_date_dict[ticker]) + timedelta(days=10)
        str_ann_date = datetime.strftime(ann_date, '%m/%d/%Y')
        str_end_date = datetime.strftime(end_date, '%m/%d/%Y')
        writer.writerow([r'=BDH("%s Equity","Px_Last","%s","%s")' % (ticker, str_ann_date, str_end_date)])
        num_of_date = (end_date - ann_date).days + 1
        for i in range(num_of_date):
            writer.writerow('')
            
with open(base_dir + '1990_ma_deals_BHD_price.csv', 'rb') as f:
    data = f.read()
with open(base_dir + '1990_ma_deals_BHD_price.csv', 'wb') as g:
    g.write(data.replace('\\"', '\"').replace('Equity\"\\', 'Equity\"').replace('\"\\', '\"'))

# %% [markdown]
# #### Load the historical prices that are pulled from Bloomeberg into dataframe and dict. The daily return is in percentage

# %%
ma_deals_price_pull = load_df(base_dir + '1990_ma_deals_BHD_price_pull.csv', ['Date', 'Price'])

# %%
def add_price_lag(df, lag, forward=1):
    '''this add both the price lag and lag-days return to df'''
    df['Price Return lag' + str(lag)] = df.Price.pct_change(periods=lag).shift(-lag+forward) * 100
    df['t+1 - t'] = (((df.Price/df.Price.shift(1))-1)*100).shift(-1)
    df['t - t-1'] = df['t+1 - t'].shift(1)
    df['t+1 - t-1'] = (((df.Price.shift(-1)/df.Price.shift(1))-1)*100)
lag = 2
forward = 2
lags = range(4,5)
for lag in lags:
    add_price_lag(ma_deals_price_pull, lag, forward=forward)
ma_deals_price_pull
# Out:
#               Date     Price  Price Return lag4    t+1 - t    t - t-1  \
# 0            ZZ US       NaN                NaN        NaN        NaN
# 1        9/17/2012      2.05                NaN  -1.951220        NaN
# 2        9/18/2012      2.01                NaN   2.487562  -1.951220
# 3        9/19/2012      2.06           7.317073  -0.970874   2.487562
# 4        9/20/2012      2.04           8.457711   7.843137  -0.970874
# 5        9/21/2012      2.20           3.883495  -0.909091   7.843137
# 6        9/24/2012      2.18           4.901961  -1.834862  -0.909091
# 7        9/25/2012      2.14          -0.454545   0.000000  -1.834862
# 8        9/26/2012      2.14           0.000000   2.336449   0.000000
# 9        9/27/2012      2.19           2.336449  -0.456621   2.336449
# 10       9/28/2012      2.18           2.336449   0.458716  -0.456621
# 11       10/1/2012      2.19           1.369863   0.000000   0.458716
# 12       10/2/2012      2.19           1.834862   1.369863   0.000000
# 13       10/3/2012      2.22           3.196347   0.000000   1.369863
# 14       10/4/2012      2.22           2.739726   1.801802   0.000000
# 15       10/5/2012      2.26           0.000000  -0.442478   1.801802
# 16       10/8/2012      2.25           0.000000  -1.333333  -0.442478
# 17       10/9/2012      2.22          -2.212389   0.000000  -1.333333
# 18      10/10/2012      2.22          -1.777778  -0.450450   0.000000
# 19      10/11/2012      2.21          -0.450450   0.000000  -0.450450
# 20      10/12/2012      2.21           0.450450   0.000000   0.000000
# 21      10/15/2012      2.21           0.452489   0.904977   0.000000
# 22      10/16/2012      2.23           0.452489  -0.448430   0.904977
# 23      10/17/2012      2.22           0.452489   0.000000  -0.448430
# 24      10/18/2012      2.22          -0.896861   0.000000   0.000000
# 25      10/19/2012      2.22          -0.450450  -0.450450   0.000000
# 26      10/22/2012      2.21           0.450450   0.000000  -0.450450
# 27      10/23/2012      2.21           0.450450   0.904977   0.000000
# 28      10/24/2012      2.23           0.904977   0.000000   0.904977
# 29      10/25/2012      2.23           0.904977   0.000000   0.000000
# ...            ...       ...                ...        ...        ...
# 303561   7/15/2015  67000.00          -4.461538   3.432836   0.449775
# 303562   7/16/2015  69300.00         -10.044978 -10.389610   3.432836
# 303563   7/17/2015  62100.00         -11.641791  -3.381643 -10.389610
# 303564   7/20/2015  60000.00         -13.275613  -1.333333  -3.381643
# 303565   7/21/2015  59200.00          -4.830918   1.520270  -1.333333
# 303566   7/22/2015  60100.00          -3.333333  -1.663894   1.520270
# 303567   7/23/2015  59100.00          -2.195946  -1.861252  -1.663894
# 303568   7/24/2015  58000.00          -5.158070  -0.172414  -1.861252
# 303569   7/27/2015  57900.00          -2.707276  -1.554404  -0.172414
# 303570   7/28/2015  57000.00          -3.275862   0.877193  -1.554404
# 303571   7/29/2015  57500.00          -2.245250  -2.434783   0.877193
# 303572   7/30/2015  56100.00          -0.701754   0.891266  -2.434783
# 303573   7/31/2015  56600.00           0.173913   0.000000   0.891266
# 303574    8/3/2015  56600.00           1.960784   1.766784   0.000000
# 303575    8/4/2015  57600.00          -2.473498  -0.694444   1.766784
# 303576    8/5/2015  57200.00          -7.597173  -3.496503  -0.694444
# 303577    8/6/2015  55200.00         -10.937500  -5.253623  -3.496503
# 303578    8/7/2015  52300.00         -10.839161  -1.912046  -5.253623
# 303579   8/10/2015  51300.00          -9.963768  -0.584795  -1.912046
# 303580   8/11/2015  51000.00          -4.397706  -2.549020  -0.584795
# 303581   8/12/2015  49700.00          -3.021442   0.603622  -2.549020
# 303582   8/13/2015  50000.00          -4.509804  -0.500000   0.603622
# 303583   8/17/2015  49750.00          -8.249497  -2.110553  -0.500000
# 303584   8/18/2015  48700.00          -6.000000  -6.365503  -2.110553
# 303585   8/19/2015  45600.00          -6.130653   3.070175  -6.365503
# 303586   8/20/2015  47000.00          -8.624230  -0.638298   3.070175
# 303587   8/21/2015  46700.00           0.438596  -4.710921  -0.638298
# 303588   8/24/2015  44500.00           2.340426   2.921348  -4.710921
# 303589   8/25/2015  45800.00                NaN   5.021834   2.921348
# 303590   8/26/2015  48100.00                NaN        NaN   5.021834
#
#         t+1 - t-1
# 0             NaN
# 1             NaN
# 2        0.487805
# 3        1.492537
# 4        6.796117
# 5        6.862745
# 6       -2.727273
# 7       -1.834862
# 8        2.336449
# 9        1.869159
# 10       0.000000
# 11       0.458716
# 12       1.369863
# 13       1.369863
# 14       1.801802
# 15       1.351351
# 16      -1.769912
# 17      -1.333333
# 18      -0.450450
# 19      -0.450450
# 20       0.000000
# 21       0.904977
# 22       0.452489
# 23      -0.448430
# 24       0.000000
# 25      -0.450450
# 26      -0.450450
# 27       0.904977
# 28       0.904977
# 29       0.000000
# ...           ...
# 303561   3.898051
# 303562  -7.313433
# 303563 -13.419913
# 303564  -4.669887
# 303565   0.166667
# 303566  -0.168919
# 303567  -3.494176
# 303568  -2.030457
# 303569  -1.724138
# 303570  -0.690846
# 303571  -1.578947
# 303572  -1.565217
# 303573   0.891266
# 303574   1.766784
# 303575   1.060071
# 303576  -4.166667
# 303577  -8.566434
# 303578  -7.065217
# 303579  -2.485660
# 303580  -3.118908
# 303581  -1.960784
# 303582   0.100604
# 303583  -2.600000
# 303584  -8.341709
# 303585  -3.490760
# 303586   2.412281
# 303587  -5.319149
# 303588  -1.927195
# 303589   8.089888
# 303590        NaN
#
# [303591 rows x 6 columns]

# %%
def remove_last_n_rows(price_dict, lag, forward):
    # delete the last len(df) - (lag-forward) rows because the returns are not available
    for ticker, df in price_dict.items():
        price_dict[ticker] = df[: len(df) - (lag-forward)]
    return price_dict
    
ticker_price_dict = load_ticker_dict(ma_deals_price_pull, 'Price', 'Date')
ticker_price_dict = remove_last_n_rows(ticker_price_dict, 4, 2)

# %%
import re
def choose_return(time):
    returns = []
#     for time in time:
    if isinstance(time, str):
        if ':' in time:
            four = datetime.strptime('16:00', '%H:%M')
            if re.findall('AM', time, re.IGNORECASE) or re.findall('PM', time, re.IGNORECASE):
                time = datetime.strptime(time, '%I:%M%p')
            else:
                time = datetime.strptime(time, '%H:%M')
            time_diff = (four - time).total_seconds()
            if time_diff > 0:
                returns.append('t - t-1')
            else:
                returns.append('t+1 - t')
        elif 'Bef-mkt' == time:
            returns.append('t - t-1')
        elif 'Aft-mkt' == time:
            returns.append('t+1 - t')
        else:
            returns.append('t+1 - t-1')
    else:
        returns.append('t+1 - t-1')
    return returns[0]
        
# print choose_return('08:00PM')
# print choose_return('20:30')
# print choose_return('Aft-mkt')
# print choose_return('Bef-mkt')
# print choose_return(ma_deals_eps_pull['Time'].values[0])

# %% [markdown]
# #### each eps date has a return %, take the mean and std of the returns across all stocks. Store the mean and std of returns for each Action ID

# %%
# picking the one-day return according to the time
no_eps_list = []
concat_eps_return_list = []
for index, row in ma_deals.iterrows():
    actionid = row['Action ID']
    target_ticker = row['Target Ticker']
    if str(target_ticker) != 'nan':  # 4 tickers are nan in our MA deals
#         if actionid == 132864185:
            eps_df = actionid_eps_dict[actionid]
            df = eps_df.merge(ticker_price_dict[target_ticker], on='Date', how='left')
            df['Action ID'] = actionid
            df['Target Ticker'] = target_ticker
            df['Payment Type'] = row['Payment Type']
            df['Target Industry Sector'] = row['Target Industry Sector']
            df['Cash Terms'] = row['Cash Terms']
            
            for lag in lags:
                col_name = 'Price Return lag' + str(lag)
                ma_deals.loc[index, 'Mean ' + col_name] = df[col_name].mean()
                ma_deals.loc[index, 'Mean t+1 - t'] = df['t+1 - t'].mean()
                ma_deals.loc[index, 'Mean t - t-1'] = df['t - t-1'].mean()
                ma_deals.loc[index, 'Mean t+1 - t-1'] = df['t+1 - t-1'].mean()
                
            if len(df):  # some deals have no earnings reported during the deal period
                df['Return Used'] = [row[choose_return(row['Time'])] for index, row in df.iterrows()]
                concat_eps_return_list.append(df)
            else:
                no_eps_list.append(actionid)
                
def determine_delta_spread(res):
    delta_spread = []
    delta_spread_percentage = []
    for i, row in res.iterrows():
        time = choose_return(row['Time'])
        delta = 0
        delta_percentage = 0
        if time == 't+1 - t-1' or time == 't+1 - t':
            time = 't+1 - t'
            delta = row[time + ' Spread'] - row['Spread']
            if row['Spread'] != 0:
                delta_percentage = delta / row['Spread']
            else:
                delta_percentage = None
        else:
            delta = row['Spread'] - row[time + ' Spread']
            if row[time + ' Spread'] != 0:
                delta_percentage = delta / row[time + ' Spread']
            else:
                delta_percentage = None
        delta_spread.append(delta)
        delta_spread_percentage.append(delta_percentage)
    return delta_spread, delta_spread_percentage
    
res = pd.concat(concat_eps_return_list)
res['Cash Terms'] = res['Cash Terms'].astype(float)
res['Spread'] = (res['Cash Terms'] - res['Price']) / res['Price']
res['t+1 - t Price'] = res['Price'] * (1 + res['t+1 - t'] / 100)
res['t+1 - t Spread'] = (res['Cash Terms'] - res['t+1 - t Price']) / res['t+1 - t Price']

res['t - t-1 Price'] = res['Price'] / (1 + res['t - t-1'] / 100)
res['t - t-1 Spread'] = (res['Cash Terms'] - res['t - t-1 Price']) / res['t - t-1 Price']

res['Delta Spread'], res['Delta Spread percentage'] = determine_delta_spread(res)
res = res[res['Est EPS diff percentage'].notnull()]
res = res[res['Price'].notnull()]

ma_deals
# Out:
#      Action ID Announce Date Target Ticker  \
# 0     69224411     9/27/2012         ZZ US
# 2    112314918     11/6/2015       ZSPH US
# 3    125179220      5/5/2016       ZPIN US
# 4     81900649     9/26/2013       ZOLT US
# 5     62404789     3/12/2012       ZOLL US
# 6     43195085     2/18/2010        ZNT US
# 7    140287996     2/13/2017       ZLTQ US
# 8     87551829     2/19/2014        ZLC US
# 9     56303521     7/20/2011         ZL CN
# 10    72579414      1/2/2013        ZIP US
# 12    48043400      9/7/2010       ZGEN US
# 13   105214134      4/8/2015        ZEP US
# 14   124386594     1/19/2017         ZC FP
# 15   109424566      7/9/2015         YY US
# 16   114213333    10/16/2015       YOKU US
# 19   139414367     1/30/2017       XXIA US
# 20   146250928     5/30/2017       XTLY US
# 22    63236178     4/10/2012       XRIT US
# 23   109081535      7/1/2015       XOOM US
# 25   143625705     4/10/2017       XCRA US
# 26    49329529     11/1/2010        XCO US
# 27   115671578     10/4/2015        XCH LN
# 29   106231939     4/30/2015         WX US
# 31   128451851      7/7/2016       WWAV US
# 34    93385053      7/7/2014        WTF AU
# 36   134894105      5/9/2017       WSTC US
# 37    48751436     10/6/2010        WSM LN
# 38    74260946     2/21/2013      WSHLY US
# 39    65203199      6/7/2012        WSH LN
# 44   138420760      1/9/2017       WOOF US
# ..         ...           ...           ...
# 467   46429454     5/27/2010       PWAY SP
# 453   65410169      3/9/2012       QSFT US
# 451   59981793     1/10/2012        QSR MK
# 435   81918607     11/7/2013        RDA US
# 429  101680421     7/25/2014       RDGZ KZ
# 430  127437040     6/17/2016       RDGZ KZ
# 428  128900824     7/18/2016        RDI US
# 427  137273310    12/20/2016        RDI US
# 408  115497769     11/9/2015        RLD US
# 407   96894486     10/1/2014        RLD US
# 394   66955681      7/8/2012        RON CN
# 395  120072893      2/3/2016        RON CN
# 380   88056163      1/8/2014       RVBD US
# 370  151540895     7/19/2017        SAZ GR
# 369  126145026     4/10/2017        SAZ GR
# 332   70842739    10/30/2012        SHF US
# 316   50636225     6/15/2010        SKY LN
# 315  136679903     12/9/2016        SKY LN
# 286   45434500     3/31/2010        SPR FP
# 192   67982487    11/19/2012        TLH CN
# 177  105141648      4/7/2015       TNTE NA
# 176   61786859     2/17/2012       TNTE NA
# 171   68084055     10/8/2012       TPCG US
# 143   58668919    10/24/2011        TUC US
# 142   82598719    10/15/2013        TUC US
# 133   94798496     5/20/2014        TWE AU
# 89   148638773      6/7/2017        VOC AU
# 70    50156488     12/2/2010       WBDF RM
# 61   104722407     3/28/2015        WDF IM
# 46    63152530     3/13/2012       WOLF US
#
#                                 Target Name Acquirer Ticker  \
# 0                                Sealy Corp          TPX US
# 2                             ZS Pharma Inc          AZN LN
# 3                               Zhaopin Ltd             NaN
# 4                            Zoltek Cos Inc         3402 JP
# 5                         Zoll Medical Corp         3407 JP
# 6            Zenith National Insurance Corp          FFH CN
# 7                     Zeltiq Aesthetics Inc          AGN US
# 8                                 Zale Corp          SIG US
# 9              Microsemi Semiconductor Corp         MSCC US
# 10                               Zipcar Inc          CAR US
# 12                         ZymoGenetics Inc          BMY US
# 13                                  Zep Inc      161147Z US
# 14                         Zodiac Aerospace          SAF FP
# 15                                   YY Inc             NaN
# 16                          Youku Tudou Inc         BABA US
# 19                                     Ixia         KEYS US
# 20                              Xactly Corp      389272Z US
# 22                               X-Rite Inc          DHR US
# 23                                Xoom Corp         PYPL US
# 25                              Xcerra Corp     1334073D CH
# 26                       EXCO Resources Inc             NaN
# 27                            Xchanging Ltd          CSC US
# 29               WuXi PharmaTech Cayman Inc             NaN
# 31                   WhiteWave Foods Co/The           BN FP
# 34                   Wotif.com Holdings Ltd         EXPE US
# 36                                West Corp          APO US
# 37                  Wellstream Holdings Ltd           GE US
# 38                         WSP Holdings Ltd     0111135D US
# 39                            WSP Group Ltd          WSP CN
# 44                                  VCA Inc        4614Z US
# ..                                      ...             ...
# 467                    Parkway Holdings Ltd             NaN
# 453                   Quest Software Inc/CA         DELL US
# 451               QSR Brands M Holdings Bhd             NaN
# 435                RDA Microelectronics Inc       PDCTOZ CH
# 429  KazMunaiGas Exploration Production JSC         KMGZ KZ
# 430  KazMunaiGas Exploration Production JSC         KMGZ KZ
# 428               Reading International Inc             NaN
# 427               Reading International Inc             NaN
# 408                               RealD Inc      956022Z US
# 407                               RealD Inc     0290875D US
# 394                                RONA Inc          LOW US
# 395                                RONA Inc          LOW US
# 380                 Riverbed Technology Inc             NaN
# 370                   STADA Arzneimittel AG             NaN
# 369                   STADA Arzneimittel AG             NaN
# 332      Schiff Nutrition International Inc          RB/ LN
# 316                                 Sky PLC         FOXA US
# 315                                 Sky PLC         FOXA US
# 286                   Sperian Protection SA          HON US
# 192                     Talison Lithium Ltd          ROC US
# 177                          TNT Express BV          FDX US
# 176                          TNT Express BV          UPS US
# 171                           TPC Group Inc             NaN
# 143                           Mac-Gray Corp     0342855Z US
# 142                           Mac-Gray Corp     0883166D US
# 133               Treasury Wine Estates Ltd             NaN
# 89                          Vocus Group Ltd      AFFEQTZ HK
# 70                Wimm-Bill-Dann Foods OJSC          PEP US
# 61                      World Duty Free SpA         DUFN SW
# 46                   Great Wolf Resorts Inc      730174Z US
#
#     Announced Total Value (mil.) Payment Type Deal Status  \
# 0                         909.51         Cash   Completed
# 2                         2037.6         Cash   Completed
# 3                          487.8         Cash     Pending
# 4                         575.46         Cash   Completed
# 5                        2062.85         Cash   Completed
# 6                        1320.99         Cash   Completed
# 7                        2309.42         Cash   Completed
# 34                   11/18/2014        3.3          Communications
# 36                   10/11/2017       23.5          Communications
# 37                     3/8/2011       7.86                  Energy
# 38                    5/31/2014        3.2                  Energy
# 39                     8/2/2012       4.35              Industrial
# 44                    9/13/2017         93  Consumer, Non-cyclical
# ..                          ...        ...                     ...
# 467                  11/24/2010       3.95  Consumer, Non-cyclical
# 453                  10/01/2012         28              Technology
# 451                  02/07/2013        6.9      Consumer, Cyclical
# 435                  07/21/2014       18.5              Technology
# 429                    1/5/2015       18.5                  Energy
# 430                    8/3/2016      47.27                  Energy
# 428                   7/18/2016         17      Consumer, Cyclical
# 427                                   18.5      Consumer, Cyclical
# 408                   3/22/2016         11              Technology
# 407                   11/3/2014         12              Technology
# 394                   9/17/2012       14.5      Consumer, Cyclical
# 395                   5/25/2016         24      Consumer, Cyclical
# 380                  12/15/2014         21              Technology
# 370                                   74.4  Consumer, Non-cyclical
# 369                   6/22/2017      65.28  Consumer, Non-cyclical
# 332                  12/17/2012         42  Consumer, Non-cyclical
# 316                   7/13/2011          7          Communications
# 315                   6/30/2018      10.75          Communications
# 286                  10/12/2010         70              Industrial
# 192                  12/12/2012        7.5         Basic Materials
# 177                    7/4/2016          8              Industrial
# 176                   1/14/2013        9.5              Industrial
# 171                  12/21/2012       47.5         Basic Materials
# 143                   1/22/2012       17.5  Consumer, Non-cyclical
# 142                    1/9/2014      21.25  Consumer, Non-cyclical
# 133                  09/29/2014        5.2  Consumer, Non-cyclical
# 89                   08/21/2017        3.5          Communications
# 70                   02/10/2011     3883.7  Consumer, Non-cyclical
# 61                   11/13/2015      10.25      Consumer, Cyclical
# 46                   05/07/2012       7.85      Consumer, Cyclical
#
#      Mean Price Return lag4  Mean t+1 - t  Mean t - t-1  Mean t+1 - t-1
# 0                  0.000000     -0.917431      0.000000       -0.917431
# 2                 42.220818      0.213435     -0.022462        0.190925
# 3                  1.443973     -0.162103      1.749794        1.597535
# 4                  0.179533      0.059773      0.030119        0.089910
# 5                       NaN           NaN           NaN             NaN
# 6                  0.104248     -0.052110      0.000000       -0.052110
# 7                  0.360490      0.108147      0.216763        0.325145
# 8                 -0.190338      0.670783     -0.103448        0.563902
# 9                  0.821918      0.273224      1.385042        1.662050
# 10                -0.163399     -0.081699      0.000000       -0.081699
# 12                      NaN           NaN           NaN             NaN
# 13                      NaN           NaN           NaN             NaN
# 14                 1.904534      0.142802      3.522456        3.657206
# 15                 1.932659      1.444115     -1.210751        0.200038
# 16                 1.397281      0.374532      0.413689        0.789771
# 19                 0.255754     -0.510204      0.512821        0.000000
# 20                 0.127551     -0.318471      0.000000       -0.318471
# 22                 0.000000      0.180505      0.000000        0.180505
# 23                -0.160015     -0.140651     -0.160192       -0.300135
# 25                 1.251767     -0.029003      1.264487        1.235511
# 26                 8.147036     -1.362894     -0.050664       -1.415234
# 27                -0.923483     -0.923483     -0.131752       -1.054018
# 29                 1.175532      2.675498     -0.099958        2.564966
# 31                 0.071299     -0.461669      0.276623       -0.187995
# 34                 0.303030      0.000000      0.302115        0.302115
# 0        0.065891       10.3900       0.058710      0.005139
# 0        0.042416       13.7500       0.054545      0.001536
# 0        0.007557       23.8300       0.007134      0.000423
# 1        0.021711       23.4300       0.024328      0.000437
# 0        0.108765       18.1600       0.156388     -0.019055
# 1        0.142546       17.9000       0.173184     -0.029983
# 2        0.079692       19.6500       0.068702      0.013702
# 3        0.064909       19.4800       0.078029      0.003230
# 0        0.006615       64.6820       0.009245      0.000500
# 0       -0.991736      834.5000      -0.991612     -0.000075
# 1       -0.990789      757.5000      -0.990759     -0.000061
# 2       -0.990071      697.5000      -0.989964     -0.000057
# 3       -0.990155      720.0000      -0.990278      0.000123
# 2       -0.988837      966.5000      -0.988877     -0.000017
# 0        0.009336        7.9440       0.007049      0.000763
# 1        0.013813        7.9130       0.010995      0.003074
# 2        0.045752        7.6600       0.044386      0.000000
# 3        0.043569        7.7390       0.033725     -0.002183
# 4        0.051248        7.6490       0.045888      0.004402
# 0        0.165644        8.1560       0.164787     -0.008647
# 1        0.077831        8.8120       0.078075     -0.004629
# 2        0.034182        9.1600       0.037118     -0.001131
# 3       -0.031600       10.1800      -0.066798      0.027753
# 0        0.048565       44.9800       0.056025      0.004150
# 0        0.216122       13.7200       0.275510     -0.102588
# 0        0.005203       21.0900       0.007587      0.000478
# 0        0.007752        5.3300      -0.024390      0.007752
# 0        0.038417     3719.8701       0.044042     -0.005269
# 1        0.011846       10.1000       0.014851      0.003980
#
#     Delta Spread percentage
# 0                 -0.195594
# 4                 -0.076785
# 5                  0.220249
# 0                 -0.500299
# 1                 -0.500299
# 0                 -0.000000
# 0                 -0.059840
# 0                 -0.079104
# 1                  0.122831
# 0                 -0.146950
# 0                  0.000000
# 0                 -0.228246
# 1                 -0.388291
# 0                  0.003785
# 2                  0.005174
# 3                 -0.078190
# 0                 -0.114428
# 0                 -0.668367
# 0                 -1.000000
# 0                 -1.000000
# 0                 -0.400962
# 1                  1.008878
# 0                 -0.285007
# 1                 -0.149876
# 2                 -0.364291
# 0                 -1.385135
# 1                  2.278903
# 2                  0.085384
# 0                 -0.000013
# 0                  0.000000
# ..                      ...
# 3                  0.036210
# 0                  0.084595
# 0                  0.028162
# 0                  0.059268
# 1                  0.017978
# 0                 -0.149078
# 1                 -0.173785
# 2                  0.207633
# 3                  0.052373
# 0                  0.054033
# 0                  0.000075
# 1                  0.000061
# 2                  0.000058
# 3                 -0.000124
# 2                  0.000017
# 0                  0.089059
# 1                  0.286253
# 2                  0.000000
# 3                 -0.047706
# 4                  0.093966
# 0                 -0.052474
# 1                 -0.059289
# 2                 -0.030470
# 3                 -0.415472
# 0                  0.093436
# 0                 -0.372356
# 0                  0.063004
# 0                       NaN
# 0                 -0.120604
# 1                  0.505923
#
# [1133 rows x 27 columns]

# %%
res.to_csv('ma_cash_deals_res.csv', index=False)

# %% [markdown]
# #### Some spreads are wrong due to different currencies/units in cash terms and historical prices returned from Bloomberg. Some are simply tagged as cash deal while it was a cash and stock deal(e.g. STRZA US, GNCMA US)

# %%
# filtered out those abnormal spread deals
final_res = res[res['Spread'] > -0.5]
# final_res = final_res[final_res['']]

# %%
y_label = 'Spread'
plot(final_res, lags, 'Est EPS diff percentage', y_label, axis=[-10, 5, -0.8, 2])

# %%
y_label = 'Delta Spread'
plot(final_res, lags, 'Est EPS diff percentage', y_label, axis=[-6, 2, -0.15, 0.15])

# %%
y_label = 'Delta Spread percentage'
print len(final_res)
plot(final_res, lags, 'Est EPS diff percentage', y_label, axis=[-5, 3, -1, 1])
# Out:
# 1088

# %%
# combine earnings surprises in all quarters in same deal and see the impact on spread
x_label = 'Est EPS diff percentage'
y_label = 'Delta Spread percentage'
combined_final_res = final_res.groupby(['Action ID'])[x_label, y_label].mean()
print len(combined_final_res)
plot(combined_final_res, lags, x_label, y_label, axis=[-5, 3, -1, 1])

y_label = 'Delta Spread'
combined_final_res = final_res.groupby(['Action ID'])[x_label, y_label].mean()
plot(combined_final_res, lags, x_label, y_label, axis=[-5, 3, -0.15, 0.15])
# Out:
# 686
# 686

# %%
# earnings surprise distribution
final_res['Est EPS diff'].plot.hist(stacked=True, bins=80, range=(-50, 50))
plt.show()

# def display_hist(deals, industry=False, bin=100):
#     stat_list = []
#     return_label = 'Return Used'
#     print 'count: %s' % str(len(deals))
#     stat_dict = print_stat(deals, return_label)
#     stat_dict['Industry'] = 'All'
#     stat_list.append(stat_dict)
#     deals[return_label].plot.hist(stacked=True, bins=bin)
#     plt.show()

# %% [markdown]
# #### 462 deals have no earnings data for this analysis. The average deal period is about 77 days for these deals. Some of them actually has no EPS data pulled back from Bloomberg (e.g. 0256595Z SM, BHGE US)

# %%
print 'Deal count that has no earnings during the deal period: %s' % str(len(no_eps_list))
no_eps_df = pd.DataFrame(no_eps_list, columns=['Action ID'])
no_eps_df = no_eps_df.merge(ma_deals, on='Action ID', how='left')
avg_duration(no_eps_df[no_eps_df['Completion/Termination Date'] != ' '], 'No EPS')
no_eps_df[no_eps_df['Completion/Termination Date'] == ' ']
# Out:
# Deal count that has no earnings during the deal period: 288
# Number of deals: 284. Average number of days spent on No EPS deals: 69.3063380282
#      Action ID Announce Date Target Ticker                        Target Name  \
# 96   153479333     12/8/2017        MLC LN  Millennium & Copthorne Hotels PLC
# 157  156830757     12/7/2017       ENTL US               Entellus Medical Inc
# 196  148903660     12/4/2017        BGC US                 General Cable Corp
# 238  153198656     9/15/2017        826 HK      Tiangong International Co Ltd
#
#     Acquirer Ticker Announced Total Value (mil.) Payment Type Deal Status  \
# 96           CIT SP                       908.45         Cash     Pending
# 157          SYK US                       629.89         Cash     Pending
# 196          PRY IM                      2517.74         Cash     Pending
# 238     1542639D HK                       597.85         Cash     Pending
#
#     Completion/Termination Date Cash Terms  Target Industry Sector  \
# 96                                       6      Consumer, Cyclical
# 157                                     24  Consumer, Non-cyclical
# 196                                     30              Industrial
# 238                                    0.9         Basic Materials
#
#      Mean Price Return lag4  Mean t+1 - t  Mean t - t-1  Mean t+1 - t-1
# 96                      NaN           NaN           NaN             NaN
# 157                     NaN           NaN           NaN             NaN
# 196                     NaN           NaN           NaN             NaN
# 238                     NaN           NaN           NaN             NaN

# %% [markdown]
# #### Of those 2819 earnings reaction day returns, 140 of them have NaN value. The remaining 2679 returns are used for the below analysis

# %%
print len(res)
print len(res[res['Return Used'].isnull()])
# Out:
# 1121
# 0

# %% [markdown]
# #### Some stocks may not always have estimate EPS to compare with the actual. Analysis on comparing the EPS may not be accurate

# %%
nan_est_eps_actionid_list = []
for actionid, eps_df in actionid_eps_dict.items():
    null_len = len(eps_df[eps_df['Est EPS'].isnull()])
    if null_len:
#         print eps_df[eps_df['Est EPS'].isnull()]
        nan_est_eps_actionid_list.append(actionid)
            
print 'number of deals have NaN est. EPS: ' + str(len(nan_est_eps_actionid_list))
# Out:
# number of deals have NaN est. EPS: 221

# %% [markdown]
# #### Plot the xy plot to show relation between EPS and return

# %%
# After concatenate the eps df, exclude all the NaN rows, it could be missing Est EPS
# or missing Peer EPS. Then plot the data against the price returns 
def plot(res, lags, x1_label, y_label, marks='b.', axis=None):
        frames = res[res[x1_label].isnull() == False]
        frames = frames[frames[y_label].isnull() == False]
        est_diff_x = frames[x1_label]
        y = frames[y_label]
        plt.plot(est_diff_x, y, marks)
        plt.xlabel(x1_label)
        plt.ylabel(y_label)
        if axis:
            plt.axis(axis)
        plt.show()
        
        
y_label = 'Price Return lag4'
# y_label = 'Return Used'
plot(res, lags, 'Est EPS diff', y_label, axis=[-2, 2, -15, 15])

# %%
# print nasdaq_res['Est EPS diff'].mean()
# max_eps_diff = nasdaq_res[nasdaq_res['Est EPS diff'] == max(nasdaq_res[nasdaq_res['Est EPS diff'].notnull()]['Est EPS diff'])]
# print max_eps_diff
# print min(nasdaq_res[nasdaq_res['Est EPS diff'].notnull()]['Est EPS diff'])
# print nasdaq_res['Est EPS diff'].std()
print len(res[res['Est EPS diff'].abs() > 2])
test_res = res[res['Est EPS diff'].abs() < 2]
print test_res['Est EPS diff'].mean()
print test_res['Est EPS diff'].std()
# Out:
# 36
# -0.0383073732719
# 0.284376435597

# %%
res[res['Est EPS diff'].abs() > 5]
# Out:
#    Quarter        Date     Time    Unknown        EPS   Est EPS     Date F  \
# 3   2009:A   4/14/2010      NaN     7.9438    19.2100     3.717 2010-04-14
# 0  2015:Q4   3/16/2016    17:00    -0.2580     0.6400     6.825 2016-03-16
# 0   2013:A  11/12/2013  Aft-mkt  2621.7245  2622.0000  2738.150 2013-11-12
# 4  2012:Q2   6/25/2012     9:00   115.1000   115.0600   100.785 2012-06-25
# 5  2012:Q1   4/17/2012    19:11    93.9200    93.9200    99.300 2012-04-17
# 0   2013:A    2/5/2014      NaN    -5.0600    -7.6670     0.467 2014-02-05
# 0   2011:A   5/17/2011    16:00     4.6595     3.0000    12.450 2011-05-17
# 0   2010:A   5/14/2010    15:00  -153.0942  -139.8600  -111.867 2010-05-14
# 0  2017:Q1   7/29/2016    15:00   -16.8788   -17.2800     6.030 2016-07-29
# 1   2016:A   5/12/2016    15:00  -139.1498  -154.6400  -735.107 2016-05-12
# 1   2013:A    5/9/2013    15:00  -205.8269  -401.7600  -363.481 2013-05-09
# 2  2013:Q3    2/8/2013    15:00   -62.8644  -111.8162     9.650 2013-02-08
# 3   2016:A   4/28/2016    13:00    20.7363   -60.3300    11.375 2016-04-28
# 2   2012:A   1/29/2013    12:00  6052.3600  6052.3600  5646.576 2013-01-29
# 0   2011:A   5/11/2011    15:00    39.7008    27.4900    40.320 2011-05-11
# 0  2017:Q3   1/11/2017    15:00   113.8868   112.4565   118.553 2017-01-11
# 0  2010:Q3  12/23/2010    16:00    17.2193    17.2250    28.745 2010-12-23
#
#    Est EPS diff  Est EPS diff percentage        Price  \
# 3       15.4930                 4.168146      74.5000
# 0       -6.1850                -0.906227      35.4800
# 0     -116.1500                -0.042419   27700.0000
# 4       14.2750                 0.141638    5950.0000
# 5       -5.3800                -0.054179    6250.0000
# 0       -8.1340               -17.417559     359.9000
# 0       -9.4500                -0.759036     144.0000
# 0      -27.9930                -0.250235     159.0000
# 0      -23.3100                -3.865672      92.0000
# 1      580.4670                 0.789636     130.0000
# 1      -38.2790                -0.105312     298.0000
# 2     -121.4662               -12.587171     286.0000
# 3      -71.7050                -6.303736    1494.0000
# 2      405.7840                 0.071864  108700.0000
# 0      -12.8300                -0.318204     595.0000
# 0       -6.0965                -0.051424    8200.0000
# 0      -11.5200                -0.400765    3721.1399
#
#             ...             Target Industry Sector  Cash Terms  Return Used  \
# 3           ...             Consumer, Non-cyclical        75.0     0.675676
# 0           ...                 Consumer, Cyclical        35.8    -0.028185
# 0           ...             Consumer, Non-cyclical     28000.0     0.018051
# 4           ...                          Financial      7000.0     0.847458
# 5           ...                          Financial      7000.0     0.000000
# 0           ...             Consumer, Non-cyclical       362.0     0.055586
# 0           ...                          Financial       146.0     0.694444
# 0           ...                          Financial       154.0    -0.625000
# 0           ...                 Consumer, Cyclical        88.0    -2.127660
# 1           ...                 Consumer, Cyclical        88.0    -0.763359
# 1           ...                         Technology       120.0    -1.973684
# 2           ...                         Technology       120.0    -3.050847
# 3           ...                    Basic Materials      1620.0     3.966597
# 2           ...                     Communications    123000.0    -0.091912
# 0           ...                 Consumer, Cyclical       600.0     0.000000
# 0           ...                 Consumer, Cyclical      8650.0    -0.243309
# 0           ...             Consumer, Non-cyclical      3883.7     0.507374
#
#      Spread  t+1 - t Price t+1 - t Spread t - t-1 Price t - t-1 Spread  \
# 3  0.006711          74.50       0.006711       74.0000       0.013514
# 0  0.009019          35.47       0.009304       35.5500       0.007032
# 0  0.010830       27705.00       0.010648    27735.0000       0.009555
# 4  0.176471        5900.00       0.186441     5900.0000       0.186441
# 5  0.120000        6250.00       0.120000     6300.0000       0.111111
# 0  0.005835         360.00       0.005556      359.8000       0.006115
# 0  0.013889         145.00       0.006897      144.0000       0.013889
# 0 -0.031447         160.00      -0.037500      160.0000      -0.037500
# 0 -0.043478          90.00      -0.022222       94.0000      -0.063830
# 1 -0.323077         133.00      -0.338346      131.0000      -0.328244
# 1 -0.597315         307.00      -0.609121      304.0000      -0.605263
# 2 -0.580420         262.00      -0.541985      295.0000      -0.593220
# 3  0.084337        1500.00       0.080000     1437.0000       0.127349
# 2  0.131555      109000.00       0.128440   108800.0000       0.130515
# 0  0.008403         595.00       0.008403      595.0000       0.008403
# 0  0.054878        8100.00       0.067901     8220.0000       0.052311
# 0  0.043686        3740.02       0.038417     3719.8701       0.044042
#
#    Delta Spread  Delta Spread percentage
# 3      0.000000                 0.000000
# 0      0.000284                 0.031541
# 0     -0.000182                -0.016844
# 4     -0.009970                -0.053476
# 5      0.000000                 0.000000
# 0     -0.000279                -0.047884
# 0     -0.006992                -0.503448
# 0      0.006053                -0.161426
# 0      0.020352                -0.318841
# 1      0.005167                -0.015742
# 1      0.007948                -0.013131
# 2      0.012801                -0.021578
# 3     -0.043011                -0.337744
# 2      0.001040                 0.007969
# 0      0.000000                 0.000000
# 0      0.002567                 0.049064
# 0     -0.005269                -0.120604
#
# [17 rows x 27 columns]

# %%
print res[['Est EPS diff', 'Return Used']].corr(method='spearman')
for lag in lags:
    print res[['Est EPS diff', 'Price Return lag' + str(lag)]].corr(method='spearman')
# Out:
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.129765
# Return Used       0.129765     1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.065041
# Price Return lag4      0.065041           1.000000

# %%
def earnings_surprise_count(res):
    null_eps_count = len(res[res['Est EPS diff'].isnull()])
    all_eps_count = len(res)
    available_eps_res = res[res['Est EPS diff'].notnull()]
    available_eps_count = len(available_eps_res)
    pos_eps_diff_count = len(available_eps_res[available_eps_res['Est EPS diff'] > 0])
    neg_eps_diff_count = len(available_eps_res[available_eps_res['Est EPS diff'] <= 0])
    print 'All EPS report count: ' + str(all_eps_count)
    print 'NaN EPS report count: ' + str(null_eps_count)
    print 'Available EPS count: ' + str(available_eps_count)
    print 'Positive EPS surprise count: %d (%f%%)' % (pos_eps_diff_count, pos_eps_diff_count/available_eps_count*100)
    print 'Negative EPS surprise count: %d (%f%%)' % (neg_eps_diff_count, neg_eps_diff_count/available_eps_count*100)
  
earnings_surprise_count(res)
# Out:
# All EPS report count: 1121
# NaN EPS report count: 0
# Available EPS count: 1121
# Positive EPS surprise count: 523 (46.654773%)
# Negative EPS surprise count: 598 (53.345227%)

# %% [markdown]
# #### some cases have no EPS data pulled out and some cases have only one earning report between the announcement date and completion/termination date and therefore, there is only average price return (which is the only return after the only earning report releases) and no volatilities.

# %%
# Sector
ma_deals['Target Industry Sector'].unique()
# Out:
# array(['Consumer, Cyclical', 'Consumer, Non-cyclical', 'Communications',
#        'Basic Materials', 'Financial', 'Technology', 'Industrial',
#        'Energy', 'Utilities', 'Diversified'], dtype=object)

# %%
def print_stat(df, lag):
    stat_dict = dict()
    print str(lag) + ' return'
#       mean = 'Mean Price Return lag' + str(lag)
    mean = 'Return Used'
    r_mean = df[mean]
    stat_dict['min_retun'] = min(r_mean[r_mean.isnull() == False])
    stat_dict['max_return'] = max(r_mean[r_mean.isnull() == False])
    stat_dict['mean_return'] = r_mean.mean()
    stat_dict['std_return'] = r_mean.std()
    stat_dict['avg_abs_return'] = r_mean.abs().mean()
    print 'Max: %s, Min: %s' % (stat_dict['max_return'], stat_dict['min_retun'])
    print 'Mean: %s, Std: %s' % (stat_dict['mean_return'], stat_dict['std_return'])
    print 'Avg Absolute Return %s' % (stat_dict['avg_abs_return'])
    return stat_dict
        
def display_hist(deals, industry=False, bin=100):
    stat_list = []
    return_label = 'Return Used'
    print 'count: %s' % str(len(deals))
    stat_dict = print_stat(deals, return_label)
    stat_dict['Industry'] = 'All'
    stat_list.append(stat_dict)
    deals[return_label].plot.hist(stacked=True, bins=bin)
    plt.show()
    
    if industry:
        for industry in deals['Target Industry Sector'].unique():
            sub_deals = deals[deals['Target Industry Sector'] == industry]
            stat_dict = print_stat(sub_deals, return_label)
            stat_dict['Industry'] = industry
            print '%s count: %s' % (industry, str(len(sub_deals)))
            sub_deals[return_label].plot.hist(stacked=True, bins=bin)
            plt.show()
            stat_list.append(stat_dict)
    df = pd.DataFrame(stat_list)
#     print df
    return df

# %%
# actionid = 134117432
# ma_deals[ma_deals['Action ID'] == actionid]
# actionid_eps_dict[actionid]
# df = ticker_price_dict['NXPI US']
# print df[df['Date'] == '10/25/2017']
# print df[df['Date'] == '8/2/2017']
# print df[df['Date'] == '5/3/2017']
# print df[df['Date'] == '2/1/2017']
# res.to_csv('ma_res.csv', index=False)

# %%
res_df = display_hist(res, industry=True)
# Out:
# count: 1121
# Return Used return
# Max: 46.5460526316, Min: -14.5157470992
# Mean: 0.0649714273652, Std: 2.18160148181
# Avg Absolute Return 0.822496178204
# Return Used return
# Max: 8.74635568513, Min: -14.5157470992
# Mean: -0.0755651948699, Std: 1.87996230999
# Avg Absolute Return 0.847890523229
# Consumer, Non-cyclical count: 247
# Return Used return
# Max: 8.42719227675, Min: -2.4254473161
# Mean: 0.139306134756, Std: 1.37633497084
# Avg Absolute Return 0.692504896312
# Communications count: 124
# Return Used return
# Max: 4.87804878049, Min: -3.87876884422
# Mean: 0.201333059401, Std: 1.4841845191
# Avg Absolute Return 0.865214679389
# Basic Materials count: 70
# Return Used return
# Max: 11.3303269448, Min: -5.05344995141
# Mean: 0.332664389657, Std: 1.89981822187
# Avg Absolute Return 0.852725817846
# Financial count: 122
# Return Used return
# Max: 9.92287917738, Min: -13.0181818182
# Mean: -0.161440496337, Std: 2.02126951547
# Avg Absolute Return 0.908638538263
# Consumer, Cyclical count: 153
# Return Used return
# Max: 5.86734693878, Min: -6.25682066206
# Mean: -0.00139171550154, Std: 1.41905632805
# Avg Absolute Return 0.78082254118
# Technology count: 156
# Return Used return
# Max: 46.5460526316, Min: -4.19161676647
# Mean: 0.365910795199, Std: 4.37310466712
# Avg Absolute Return 0.9962723643
# Industrial count: 131
# Return Used return
# Max: 6.875, Min: -6.10169491525
# Mean: -0.0839408041896, Std: 1.69856068062
# Avg Absolute Return 0.890462093548
# Energy count: 57
# Return Used return
# Max: 2.39043824701, Min: -2.50896057348
# Mean: 0.0218843004783, Std: 0.598934265773
# Avg Absolute Return 0.333717336974
# Utilities count: 60
# Return Used return
# Max: 0.0, Min: 0.0
# Mean: 0.0, Std: nan
# Avg Absolute Return 0.0
# Diversified count: 1

# %%
res_df.sort_values('avg_abs_return').plot(x='Industry', y='avg_abs_return', kind='bar', rot =70)
plt.show()

res_df.sort_values('mean_return').plot(x='Industry', y='mean_return', kind='bar', rot =80)
plt.show()

res_df.sort_values('std_return').plot(x='Industry', y='std_return', kind='bar', rot =80)
plt.show()

res_df
# Out:
#                   Industry  avg_abs_return  max_return  mean_return  \
# 0                      All        0.822496   46.546053     0.064971
# 1   Consumer, Non-cyclical        0.847891    8.746356    -0.075565
# 2           Communications        0.692505    8.427192     0.139306
# 3          Basic Materials        0.865215    4.878049     0.201333
# 4                Financial        0.852726   11.330327     0.332664
# 5       Consumer, Cyclical        0.908639    9.922879    -0.161440
# 6               Technology        0.780823    5.867347    -0.001392
# 7               Industrial        0.996272   46.546053     0.365911
# 8                   Energy        0.890462    6.875000    -0.083941
# 9                Utilities        0.333717    2.390438     0.021884
# 10             Diversified        0.000000    0.000000     0.000000
#
#     min_retun  std_return
# 0  -14.515747    2.181601
# 1  -14.515747    1.879962
# 2   -2.425447    1.376335
# 3   -3.878769    1.484185
# 4   -5.053450    1.899818
# 5  -13.018182    2.021270
# 6   -6.256821    1.419056
# 7   -4.191617    4.373105
# 8   -6.101695    1.698561
# 9   -2.508961    0.598934
# 10   0.000000         NaN

# %% [markdown]
# # NASDAQ

# %%
def write_BHD_price_csv(filename, tickers):
    with open(filename, 'wb') as csvfile:
        writer = csv.writer(csvfile, quoting=csv.QUOTE_NONE, escapechar ='\\')
        str_ann_date = '1/1/2010'
        str_end_date = '12/12/2017'
        ann_date = datetime.strptime(str_ann_date, '%m/%d/%Y')
        end_date = datetime.strptime(str_end_date, '%m/%d/%Y')
        num_of_date = (end_date - ann_date).days + 1
        for ticker in tickers.dropna():
            writer.writerow([ticker])
            writer.writerow([r'=BDH("%s Equity","Px_Last","%s","%s")' % (ticker, str_ann_date, str_end_date)])
            for i in range(2075): # num_of_date between 1/1/2010 and 12/12/2017 is 2073
                writer.writerow('')

    with open(filename, 'rb') as f:
        data = f.read()
    with open(filename, 'wb') as g:
        g.write(data.replace('\\"', '\"').replace('Equity\"\\', 'Equity\"').replace('\"\\', '\"'))

# %%
nasdaq_companylist = pd.read_csv(base_dir + 'nasdaq_companylist.csv', header=0)
nasdaq_companylist['Symbol'] = nasdaq_companylist['Symbol'] + ' US'
write_BDS_csv(base_dir + 'nasdaq_eps_hist.csv', nasdaq_companylist['Symbol'])
nasdaq_eps_pull_df = load_df(base_dir + 'nasdaq_eps_pull.csv', 
                                 ['Quarter', 'Date', 'Time', 'Unknown', 'EPS', 'Est EPS'],
                                format_date=True)
cal_eps_diff(nasdaq_eps_pull_df)
nasdaq_eps_dict = load_ticker_dict(nasdaq_eps_pull_df, 'Date', 'Quarter')
write_BHD_price_csv(base_dir + 'nasdaq_BHD_price.csv', nasdaq_companylist['Symbol'])

# %%
nasdaq_price_pull = load_df(base_dir + 'nasdaq_BHD_price_pull.csv', ['Date', 'Price'])
for lag in lags:
    add_price_lag(nasdaq_price_pull, lag)
# 898   11/6/2017  7.1000          -1.240418 -1.408451 -1.045296  -2.439024
# 899   11/7/2017  7.0000          -1.408451  0.000000 -1.408451  -1.408451
# 900   11/8/2017  7.0000           1.898571  1.228571  0.000000   1.228571
# 901   11/9/2017  7.0860           1.428571 -1.213661  1.228571   0.000000
# 902  11/10/2017  7.0000           0.197573  1.898571 -1.213661   0.661868
# 903  11/13/2017  7.1329           3.060000 -0.461243  1.898571   1.428571
# 904  11/14/2017  7.1000           3.744620  0.000000 -0.461243  -0.461243
# 905  11/15/2017  7.1000           6.546479  1.608451  0.000000   1.608451
# 906  11/16/2017  7.2142           2.112676  2.575476  1.608451   4.225352
# 907  11/17/2017  7.4000           0.496244  2.227027  2.575476   4.859860
# 908  11/20/2017  7.5648          -2.027027 -4.161379  2.227027  -2.027027
# 909  11/21/2017  7.2500          -2.839467  0.000000 -4.161379  -4.161379
# 910  11/22/2017  7.2500           2.068966  0.000000  0.000000   0.000000
# 911  11/24/2017  7.2500           1.379310  1.379310  0.000000   1.379310
# 912  11/27/2017  7.3500           0.689655  0.680272  1.379310   2.068966
# 913  11/28/2017  7.4000           0.000000 -0.675676  0.680272   0.000000
# 914  11/29/2017  7.3500          -2.702703 -0.680272 -0.675676  -1.351351
# 915  11/30/2017  7.3000           1.360544  0.684932 -0.680272   0.000000
# 916   12/1/2017  7.3500           2.054795 -2.040816  0.684932  -1.369863
# 917   12/4/2017  7.2000           0.680272  3.472222 -2.040816   1.360544
# 918   12/5/2017  7.4500           1.388889  0.000000  3.472222   3.472222
# 919   12/6/2017  7.4500           0.000000 -0.671141  0.000000  -0.671141
# 920   12/7/2017  7.4000          -1.677852 -1.351351 -0.671141  -2.013423
# 921   12/8/2017  7.3000                NaN  2.054795 -1.351351   0.675676
#
# [921 rows x 6 columns]

# %%
nasdaq_tickers = nasdaq_companylist['Symbol']
nasdaq_tickers_df = nasdaq_tickers.to_frame()

for index, row in nasdaq_tickers_df.iterrows():
    ticker = row['Symbol']
    eps_df =  nasdaq_eps_dict[ticker]
    df = eps_df.merge(nasdaq_ticker_price_dict[ticker], on='Date', how='left')
    col_name = 'Price Return lag' + str(lag)
    nasdaq_tickers_df.loc[index, 'Mean ' + col_name] = df[col_name].mean()

nasdaq_tickers_df['Sector'] = nasdaq_companylist['Sector']
nasdaq_tickers_df
# Out:
#         Symbol  Mean Price Return lag4             Sector
# 0       PIH US                3.620335            Finance
# 1      TURN US                0.133213            Finance
# 2      FLWS US               -1.782823  Consumer Services
# 3      FCCY US                0.817226            Finance
# 4      SRCE US                1.606735            Finance
# 5      VNET US               -4.149570         Technology
# 6      TWOU US                3.864128         Technology
# 7      JOBS US               -0.132021         Technology
# 8      CAFD US                3.628032   Public Utilities
# 9      EGHT US                1.184580   Public Utilities
# 10     AVHI US               -0.457388      Capital Goods
# 11     SHLM US               -0.356853   Basic Industries
# 12     AAON US                1.136165      Capital Goods
# 13     ABAX US               -1.794312      Capital Goods
# 14     ABEO US               -0.680892        Health Care
# 15    ABEOW US               16.116165        Health Care
# 16     ABIL US               -8.994899            Finance
# 17     ABMD US                2.785652        Health Care
# 18     ABLX US               14.452555        Health Care
# 19     AXAS US                0.375544             Energy
# 20     ACIU US               -1.037562        Health Care
# 21     ACIA US                4.631296         Technology
# 22     ACTG US                1.859400      Miscellaneous
# 23     ACHC US                2.309855        Health Care
# 24     ACAD US               -0.754388        Health Care
# 25     ACST US               75.836094        Health Care
# 26     AXDX US                0.788757      Capital Goods
# 27     XLRN US                1.795659        Health Care
# 28     ANCX US                2.942217            Finance
# 29     ARAY US               -0.054408        Health Care
# ...        ...                     ...                ...
# 3250   YERR US               -3.064415            Finance
# 3251   YTRA US                0.745208  Consumer Services
# 3252   YTEN US               -9.147747   Basic Industries
# 3253    YIN US               -4.530956            Finance
# 3254   YOGA US              -16.081401  Consumer Services
# 3255   YGYI US                1.240033  Consumer Services
# 3256   YRCW US               -6.888084     Transportation
# 3257   YECO US              192.307692      Capital Goods
# 3258     YY US                1.733351         Technology
# 3259   ZFGN US                0.933406        Health Care
# 3260   ZAGG US               -1.091500  Consumer Services
# 3261   ZLAB US                     NaN        Health Care
# 3262   ZAIS US               -5.176955            Finance
# 3263   ZEAL US                2.907158        Health Care
# 3264   ZBRA US                0.164397         Technology
# 3265      Z US               -1.199914      Miscellaneous
# 3266     ZG US                1.230103      Miscellaneous
# 3267     ZN US               -1.408671             Energy
# 3268  ZNWAA US                     NaN             Energy
# 3269   ZION US                0.893486            Finance
# 3270  ZIONW US               -0.599249            Finance
# 3271  ZIONZ US                2.782066            Finance
# 3272   ZIOP US                0.483065        Health Care
# 3273   ZIXI US               -1.640600         Technology
# 3274   ZKIN US                     NaN      Capital Goods
# 3275   ZGNX US               -2.157238        Health Care
# 3276   ZSAN US               -5.244574        Health Care
# 3277   ZUMZ US               -2.834645  Consumer Services
# 3278   ZYNE US                9.464633        Health Care
# 3279   ZNGA US                2.008581         Technology
#
# [3280 rows x 3 columns]

# %%
def exchange_eps_price_return_concat(deals, eps_dict, ticker_price_dict):
    concat_eps_return_list = []
    for index, row in deals.iterrows():
        ticker = row['Symbol']
        eps_df =  eps_dict[ticker]
        df = eps_df.merge(ticker_price_dict[ticker], on='Date', how='left')
        df['Symbol'] = ticker
        df['Target Industry Sector'] = row['Sector']
        if len(df):
            df['Return Used'] = [row[choose_return(row['Time'])] for index, row in df.iterrows()]
            concat_eps_return_list.append(df)
    return pd.concat(concat_eps_return_list)


nasdaq_res = exchange_eps_price_return_concat(nasdaq_tickers_df, nasdaq_eps_dict, nasdaq_ticker_price_dict)

# %% [markdown]
# #### 123515 returns linked to earnings reaction day in NASDAQ and 61159 have NaN. Most of them because the dates are outside our sample, only 4335 of them are NaN and after 2010

# %%
print len(nasdaq_res)
print len(nasdaq_res[nasdaq_res['Return Used'].isnull()])
nan_return_df = nasdaq_res[nasdaq_res['Return Used'].isnull()]
nan_return_df[nan_return_df['Date F'] > datetime.strptime('1/1/2010', '%m/%d/%Y')]
# Out:
# 123515
# 61155
#     Quarter        Date   Time  Unknown     EPS  Est EPS     Date F  \
# 19  2012:Q4   1/28/2013  16:10   0.1932  0.4400      NaN 2013-01-28
# 30  2010:Q1   4/19/2010  16:10  -0.5700 -0.5700      NaN 2010-04-19
# 31  2009:Q4   1/25/2010  16:12  -1.2518 -0.7900      NaN 2010-01-25
# 1   2017:Q2   7/25/2017  16:10   0.7331  0.7300      NaN 2017-07-25
# 5   2016:Q2   7/26/2016  16:10   0.4411  0.4800      NaN 2016-07-26
# 6   2016:Q1   4/25/2016  16:10   0.3950  0.3800      NaN 2016-04-25
# 7   2015:Q4   1/25/2016  16:10   0.4443  0.4300      NaN 2016-01-25
# 8   2015:Q3  10/19/2015  16:11   0.4262  0.4100      NaN 2015-10-19
# 9   2015:Q2   7/20/2015  16:10  -0.0094  0.4100      NaN 2015-07-20
# 10  2015:Q1   4/20/2015  16:10   0.3797  0.3700      NaN 2015-04-20
# 11  2014:Q4   1/26/2015  16:10   0.3348  0.4000      NaN 2015-01-26
# 12  2014:Q3  10/20/2014  16:09   0.5626  0.3800      NaN 2014-10-20
# 14  2014:Q1   4/21/2014  16:10   0.4300  0.3100      NaN 2014-04-21
# 20  2012:Q3  10/22/2012  16:10   0.3400  0.3400      NaN 2012-10-22
# 21  2012:Q2   7/23/2012  16:10   0.3000  0.3000      NaN 2012-07-23
# 22  2012:Q1   4/23/2012  16:10   0.1400  0.1400      NaN 2012-04-23
# 23  2011:Q4   1/23/2012  16:10   0.2400  0.2800      NaN 2012-01-23
# 24  2011:Q3  10/24/2011  16:10   0.3500  0.4000      NaN 2011-10-24
# 25  2011:Q2   7/18/2011  16:10   0.1600  0.1600      NaN 2011-07-18
# 26  2011:Q1   4/18/2011  17:00   0.0800  0.0900      NaN 2011-04-18
# 27  2010:Q4   1/24/2011  16:10  -0.6200 -0.6200      NaN 2011-01-24
# 28  2010:Q3  10/18/2010  16:10  -0.4177 -0.4700      NaN 2010-10-18
# 29  2010:Q2   7/19/2010  16:10  -0.8400 -0.8400      NaN 2010-07-19
# 30  2010:Q1   4/19/2010  16:10  -0.5700 -0.5700      NaN 2010-04-19
# 31  2009:Q4   1/25/2010  16:12  -1.2518 -0.7900      NaN 2010-01-25
#
#     Est EPS diff  Est EPS diff percentage  Price  Price Return lag4  t+1 - t  \
# 22          0.03                     0.15    NaN                NaN      NaN
# 27         -0.02                    -0.10    NaN                NaN      NaN
# 1            NaN                      NaN    NaN                NaN      NaN
# 3            NaN                      NaN    NaN                NaN      NaN
# 8            NaN                      NaN    NaN                NaN      NaN
# 11           NaN                      NaN    NaN                NaN      NaN
# 12           NaN                      NaN    NaN                NaN      NaN
# 13           NaN                      NaN    NaN                NaN      NaN
# 14           NaN                      NaN    NaN                NaN      NaN
# 15           NaN                      NaN    NaN                NaN      NaN
# 16           NaN                      NaN    NaN                NaN      NaN
# 17           NaN                      NaN    NaN                NaN      NaN
# 18           NaN                      NaN    NaN                NaN      NaN
# 19           NaN                      NaN    NaN                NaN      NaN
# 20           NaN                      NaN    NaN                NaN      NaN
# 21           NaN                      NaN    NaN                NaN      NaN
# 20      NaN        NaN  ABEOW US            Health Care          NaN
# 21      NaN        NaN  ABEOW US            Health Care          NaN
# 22      NaN        NaN  ABEOW US            Health Care          NaN
# 23      NaN        NaN  ABEOW US            Health Care          NaN
# 24      NaN        NaN  ABEOW US            Health Care          NaN
# 25      NaN        NaN  ABEOW US            Health Care          NaN
# 7       NaN        NaN   ABIL US                Finance          NaN
# 8       NaN        NaN   ABIL US                Finance          NaN
# 0       NaN        NaN   ABLX US            Health Care          NaN
# 1       NaN        NaN   ABLX US            Health Care          NaN
# 2       NaN        NaN   ABLX US            Health Care          NaN
# 4       NaN        NaN   ABLX US            Health Care          NaN
# 5       NaN        NaN   ABLX US            Health Care          NaN
# 6       NaN        NaN   ABLX US            Health Care          NaN
# 7       NaN        NaN   ABLX US            Health Care          NaN
# 8       NaN        NaN   ABLX US            Health Care          NaN
# ..      ...        ...       ...                    ...          ...
# 29      NaN        NaN  ZNWAA US                 Energy          NaN
# 30      NaN        NaN  ZNWAA US                 Energy          NaN
# 31      NaN        NaN  ZNWAA US                 Energy          NaN
# 0       NaN        NaN  ZIONW US                Finance          NaN
# 12      NaN        NaN  ZIONW US                Finance          NaN
# 19      NaN        NaN  ZIONW US                Finance          NaN
# 30      NaN        NaN  ZIONW US                Finance          NaN
# 31      NaN        NaN  ZIONW US                Finance          NaN
# 1       NaN        NaN  ZIONZ US                Finance          NaN
# 5       NaN        NaN  ZIONZ US                Finance          NaN
# 6       NaN        NaN  ZIONZ US                Finance          NaN
# 7       NaN        NaN  ZIONZ US                Finance          NaN
# 8       NaN        NaN  ZIONZ US                Finance          NaN
# 9       NaN        NaN  ZIONZ US                Finance          NaN
# 10      NaN        NaN  ZIONZ US                Finance          NaN
# 11      NaN        NaN  ZIONZ US                Finance          NaN
# 12      NaN        NaN  ZIONZ US                Finance          NaN
# 14      NaN        NaN  ZIONZ US                Finance          NaN
# 20      NaN        NaN  ZIONZ US                Finance          NaN
# 21      NaN        NaN  ZIONZ US                Finance          NaN
# 22      NaN        NaN  ZIONZ US                Finance          NaN
# 23      NaN        NaN  ZIONZ US                Finance          NaN
# 24      NaN        NaN  ZIONZ US                Finance          NaN
# 25      NaN        NaN  ZIONZ US                Finance          NaN
# 26      NaN        NaN  ZIONZ US                Finance          NaN
# 27      NaN        NaN  ZIONZ US                Finance          NaN
# 28      NaN        NaN  ZIONZ US                Finance          NaN
# 29      NaN        NaN  ZIONZ US                Finance          NaN
# 30      NaN        NaN  ZIONZ US                Finance          NaN
# 31      NaN        NaN  ZIONZ US                Finance          NaN
#
# [4331 rows x 17 columns]

# %%
earnings_surprise_count(nasdaq_res)
# Out:
# All EPS report count: 123515
# NaN EPS report count: 49059
# Available EPS count: 74456
# Positive EPS surprise count: 47865 (64.286290%)
# Negative EPS surprise count: 26591 (35.713710%)

# %%
temp_res = nasdaq_res[nasdaq_res['Est EPS diff percentage'].notnull()]
temp_res = temp_res[temp_res['Price'].notnull()]
temp_res.to_csv('temp_nasdaq.csv', index=False)
print len(temp_res)
print len(nasdaq_res)
# Out:
# 45587
# 123515

# %%
y_label = 'Price Return lag4'
# y_label = 'Return Used'
plot(temp_res, lags, 'Est EPS diff percentage', y_label, axis=[-20, 20, -70, 70])
plot(temp_res, lags, 'Est EPS diff percentage', 'Return Used', axis=[-20, 20, -70, 70])

# %%
nasdaq_res
# Out:
#     Quarter        Date     Time  Unknown     EPS  Est EPS     Date F  \
# 0   2017:Q3  11/13/2017    16:01  -0.3800     NaN      NaN 2017-11-13
# 1   2017:Q2   8/10/2017    16:05   0.1500     NaN      NaN 2017-08-10
# 2   2017:Q1   5/11/2017    10:56   0.0400     NaN      NaN 2017-05-11
# 3   2016:Q4   3/16/2017    16:05   0.2700     NaN      NaN 2017-03-16
# 4   2016:Q3  11/14/2016    16:05  -0.3000     NaN      NaN 2016-11-14
# 5   2016:Q2   8/11/2016    16:05   0.2200     NaN      NaN 2016-08-11
# 6   2016:Q1   5/12/2016    16:05  -0.1800     NaN      NaN 2016-05-12
# 7   2015:Q4   3/17/2016    16:05   0.0900     NaN      NaN 2016-03-17
# 8   2015:Q3  11/12/2015    16:49  -0.0200     NaN      NaN 2015-11-12
# 9   2015:Q2   8/13/2015    16:05  -0.0200     NaN      NaN 2015-08-13
# 10  2015:Q1   5/14/2015    16:30   0.2589     NaN      NaN 2015-05-14
# 11  2014:Q4   3/27/2015     7:00   0.1100     NaN      NaN 2015-03-27
# 0   2017:Q3   11/1/2017  Aft-mkt      NaN     NaN      NaN 2017-11-01
# 1   2017:Q2    8/1/2017    22:28      NaN     NaN      NaN 2017-08-01
# 2   2017:Q1    5/1/2017    22:43      NaN     NaN      NaN 2017-05-01
# 3   2016:Q4   3/15/2017    21:24  -0.0444     NaN      NaN 2017-03-15
# 4   2016:Q3  11/15/2016  Bef-mkt  -0.0354     NaN      NaN 2016-11-15
# 5   2016:Q2    8/9/2016     6:03  -0.0370     NaN      NaN 2016-08-09
# 6   2016:Q1    5/9/2016      NaN  -0.0429     NaN      NaN 2016-05-09
# 7   2015:Q4   3/15/2016      NaN  -0.0653     NaN      NaN 2016-03-15
# 8   2015:Q3   11/9/2015      NaN  -0.0527 -0.5400      NaN 2015-11-09
# 9   2015:Q2   8/10/2015      NaN  -0.0536 -0.0536      NaN 2015-08-10
# 10  2015:Q1   5/11/2015      NaN  -0.0739 -0.1200      NaN 2015-05-11
# 11  2014:Q4   3/16/2015    17:15  -0.0600 -0.3300      NaN 2015-03-16
# 12  2014:Q3  11/10/2014      NaN  -0.0610 -0.0300      NaN 2014-11-10
# 13  2014:Q2    8/8/2014      NaN  -0.0668  0.1400      NaN 2014-08-08
# 14  2014:Q1    5/8/2014      NaN  -0.0657 -0.0600      NaN 2014-05-08
# 15  2013:Q4   3/17/2014      NaN  -0.0700 -0.2500      NaN 2014-03-17
# 16  2013:Q3  11/12/2013      NaN  -0.0635 -0.0700      NaN 2013-11-12
# 17  2013:Q2    8/9/2013      NaN  -0.0659  0.1300      NaN 2013-08-09
# ..      ...         ...      ...      ...     ...      ...        ...
# 7            NaN                      NaN   5.4000          -0.891266
# 8            NaN                      NaN   7.1700           5.218618
# 9            NaN                      NaN   7.7900          -2.053915
# 10           NaN                      NaN   7.4400           1.333333
# 11           NaN                      NaN   7.5500          -0.393185
# 0            NaN                      NaN   1.8800           7.407407
# 1            NaN                      NaN   1.6000           3.125000
# 2            NaN                      NaN   1.4300           8.715278
# 3            NaN                      NaN   1.3200           1.679104
# 4            NaN                      NaN   1.2400          -2.400000
# 5            NaN                      NaN   1.5400          -0.632911
# 6            NaN                      NaN   1.7200          -2.312139
# 7            NaN                      NaN   1.8900           0.263158
# 8            NaN                      NaN   2.1100          -4.205607
# 9            NaN                      NaN   2.3600           7.487500
# 10           NaN                      NaN   2.9100          -2.739726
# 11           NaN                      NaN   3.1300          -7.232704
# 12           NaN                      NaN   2.7900           1.132616
# 13           NaN                      NaN   3.1200           0.000000
# 14           NaN                      NaN   3.5100           3.244838
# 15           NaN                      NaN   3.5800          -5.600000
# 16           NaN                      NaN   3.0400           0.651466
# 17           NaN                      NaN   3.1700          -0.630915
# ..           ...                      ...      ...                ...
# 4         0.0460                 0.064246  14.2300           6.568266
# 5        -0.1760                -0.335878   9.9100           7.773109
# 6         0.0280                 0.054054   6.2200          -6.351551
# 7         0.0050                 0.008000  21.0300          70.616114
# 8            NaN                      NaN  13.0500          -0.703125
# 9            NaN                      NaN  25.6700          20.439560
# 0         0.0106                 0.481818   3.6700          -0.777202
# 1        -0.0017                -0.094444   3.5800           1.933702
# 2         0.0150                 1.000000   2.8400          10.344828
# 3         0.0070                 0.538462   2.5200           3.200000
# 4         0.0076                 0.760000   2.7400          -1.428571
# 5         0.0000                      NaN   2.9700          -6.418919
# 6         0.0100                 1.000000   2.3000           9.913793
# 7        -0.0010                -1.000000   2.1300         -10.837438
# 8         0.0130                 1.000000   2.4500           6.694561
# 9         0.0110                 0.523810   2.4500           5.179283
# 10        0.0110                 0.523810   2.6100          12.000000
# 11        0.0000                      NaN   2.6600         -20.284698
# 12        0.0010                 0.090909   2.3600           3.404255
# 13       -0.0020                -1.000000   2.9200           3.225806
# 14        0.0020                 0.166667   4.4200          -4.605263
# 15        0.0090                 0.230769   3.5600          28.654971
# 16        0.0230                 0.534884   3.5350           5.190409
# 17        0.0250                 0.714286   3.5000          -8.231707
# 18        0.0450                 1.285714   3.3490          -1.572327
# 19        0.0400                 1.333333   2.7400          16.796875
# 20        0.0060                 1.000000   2.1290           8.636364
# 21       -0.0450                -0.818182   5.0780         -35.401831
# 22        0.0110                 0.224490   9.4200          -6.476400
# 23        0.0160                 0.470588  14.3520         -12.057530
#
#       t+1 - t     t - t-1  t+1 - t-1  Price Return lag3  Price Return lag4  \
# 0   -0.461243    1.898571   1.428571           1.428571           3.060000
# 1    2.158273   -1.516225   0.609324           1.317840           8.403004
# 2    2.797203    0.000000   2.797203           6.293706           2.097902
# 3    6.896552    0.694444   7.638889           5.555556           6.409722
# 4   -2.779167   -1.210175  -3.955709          -2.582256           2.220027
# 5    5.595238   -0.645161   4.913978           5.683564           3.686636
# 18  -6.539265    5.314465  -1.572327           5.345912           2.830189
# 19   9.124088    7.031250  16.796875          20.703125          33.984375
# 20  12.259277   -3.227273   8.636364           5.000000           1.822727
# 21 -37.475384    3.316378 -35.401831         -37.232960         -38.758901
# 22  -9.554140    3.402854  -6.476400          -8.507135          -7.135016
# 23 -17.774526    6.952828 -12.057530         -10.164692          -3.644087
#
#      Symbol Target Industry Sector  Return Used
# 0    PIH US                Finance    -0.461243
# 1    PIH US                Finance     2.158273
# 2    PIH US                Finance     0.000000
# 3    PIH US                Finance     6.896552
# 4    PIH US                Finance    -2.779167
# 5    PIH US                Finance     5.595238
# 6    PIH US                Finance     7.030875
# 7    PIH US                Finance     2.962963
# 8    PIH US                Finance     4.044630
# 9    PIH US                Finance    -2.053915
# 10   PIH US                Finance     2.150538
# 11   PIH US                Finance    -1.048493
# 0   TURN US                Finance     7.978723
# 1   TURN US                Finance     3.125000
# 2   TURN US                Finance     9.475524
# 3   TURN US                Finance     3.219697
# 4   TURN US                Finance    -0.800000
# 5   TURN US                Finance    -2.531646
# 6   TURN US                Finance    -2.312139
# 7   TURN US                Finance     0.263158
# 8   TURN US                Finance    -4.205607
# 9   TURN US                Finance     7.487500
# 10  TURN US                Finance    -2.739726
# 11  TURN US                Finance    -5.750799
# 12  TURN US                Finance     1.132616
# 13  TURN US                Finance     0.000000
# 14  TURN US                Finance     3.244838
# 15  TURN US                Finance    -5.600000
# 16  TURN US                Finance     0.651466
# 17  TURN US                Finance    -0.630915
# ..      ...                    ...          ...
# 4   ZYNE US            Health Care     5.018450
# 5   ZYNE US            Health Care     4.096639
# 6   ZYNE US            Health Care    -8.124077
# 7   ZYNE US            Health Care   149.170616
# 8   ZYNE US            Health Care    -2.605364
# 9   ZYNE US            Health Care    20.439560
# 0   ZNGA US             Technology     4.359673
# 1   ZNGA US             Technology     3.072626
# 2   ZNGA US             Technology    12.676056
# 3   ZNGA US             Technology     2.380952
# 4   ZNGA US             Technology     0.729927
# 5   ZNGA US             Technology    -6.734007
# 6   ZNGA US             Technology    10.869565
# 7   ZNGA US             Technology   -15.023474
# 8   ZNGA US             Technology     4.081633
# 9   ZNGA US             Technology     7.755102
# 10  ZNGA US             Technology     7.279693
# 11  ZNGA US             Technology   -15.789474
# 12  ZNGA US             Technology     2.966102
# 13  ZNGA US             Technology    -1.369863
# 14  ZNGA US             Technology    -1.583710
# 15  ZNGA US             Technology    23.595506
# 16  ZNGA US             Technology     5.487977
# 17  ZNGA US             Technology   -14.000000
# 18  ZNGA US             Technology    -6.539265
# 19  ZNGA US             Technology     9.124088
# 20  ZNGA US             Technology    12.259277
# 21  ZNGA US             Technology   -37.475384
# 22  ZNGA US             Technology    -9.554140
# 23  ZNGA US             Technology   -17.774526
#
# [123515 rows x 19 columns]

# %%
# print nasdaq_res['Est EPS diff'].mean()
# max_eps_diff = nasdaq_res[nasdaq_res['Est EPS diff'] == max(nasdaq_res[nasdaq_res['Est EPS diff'].notnull()]['Est EPS diff'])]
# print max_eps_diff
# print min(nasdaq_res[nasdaq_res['Est EPS diff'].notnull()]['Est EPS diff'])
# print nasdaq_res['Est EPS diff'].std()
print len(nasdaq_res[nasdaq_res['Est EPS diff'].abs() > 2])
test_res = nasdaq_res[nasdaq_res['Est EPS diff'].abs() < 2]
print test_res['Est EPS diff'].mean()
print test_res['Est EPS diff'].std()
# Out:
# 2621
# 0.053949167502
# 0.292592044295

# %%
print nasdaq_res[['Est EPS diff', 'Return Used']].corr(method='spearman')
for lag in lags:
    print nasdaq_res[['Est EPS diff', 'Price Return lag' + str(lag)]].corr(method='spearman')
# Out:
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.271959
# Return Used       0.271959     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.266058
# Price Return lag2      0.266058           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.250397
# Price Return lag3      0.250397           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.239458
# Price Return lag4      0.239458           1.000000

# %%
nasdaq_res_df = display_hist(nasdaq_res, industry=True)
# Out:
# count: 123515
# Return Used return
# Max: 8354.54545455, Min: -75.2631578947
# Mean: 0.244547317678, Std: 35.5802828384
# Avg Absolute Return 5.69396736865
# Return Used return
# Max: 162.411347518, Min: -75.2631578947
# Mean: 0.453139620952, Std: 5.43423469645
# Avg Absolute Return 3.03240740305
# Finance count: 25729
# Return Used return
# Max: 723.170731707, Min: -53.8461538462
# Mean: 0.156476587299, Std: 12.177267331
# Avg Absolute Return 5.69937408343
# Consumer Services count: 14519
# Return Used return
# Max: 449.822064057, Min: -70.8333333333
# Mean: 0.0394292960758, Std: 10.566070153
# Avg Absolute Return 6.76786009799
# Technology count: 22133
# Return Used return
# Max: 83.7398373984, Min: -70.0
# Mean: -0.353694272558, Std: 8.84875494819
# Avg Absolute Return 5.38377637908
# Public Utilities count: 3005
# Return Used return
# Max: 145.547073791, Min: -64.0287769784
# Mean: 0.346209989857, Std: 9.7148970206
# Avg Absolute Return 6.40043039939
# Capital Goods count: 9590
# Return Used return
# Max: 264.946536495, Min: -45.2991452991
# Mean: -0.167022752721, Std: 11.1456223785
# Avg Absolute Return 6.21995997069
# Basic Industries count: 3838
# Return Used return
# Max: 8354.54545455, Min: -65.0
# Mean: 0.368286307241, Std: 75.169893071
# Avg Absolute Return 6.6001372612
# Health Care count: 23024
# Return Used return
# Max: 342.934782609, Min: -38.446969697
# Mean: -0.00549662009999, Std: 12.5681086703
# Avg Absolute Return 5.36020897585
# Energy count: 2615
# Return Used return
# Max: 627.272727273, Min: -70.6060606061
# Mean: 0.592784473893, Std: 21.404540326
# Avg Absolute Return 7.59088800061
# Miscellaneous count: 4191
# Return Used return
# Max: 1063.93442623, Min: -68.5069984448
# Mean: 1.17878772035, Std: 32.4704702999
# Avg Absolute Return 6.61906932323
# Transportation count: 2796
# Return Used return
# Max: 48.4536082474, Min: -33.829787234
# Mean: -0.333984897312, Std: 5.37468658566
# Avg Absolute Return 3.13028188673
# n/a count: 1733
# Return Used return
# Max: 161.297264064, Min: -61.2903225806
# Mean: 0.0522241338555, Std: 9.42078759079
# Avg Absolute Return 5.85368411342
# Consumer Non-Durables count: 5975
# Return Used return
# Max: 81.4159292035, Min: -47.8260869565
# Mean: -0.00302956828359, Std: 10.2125027079
# Avg Absolute Return 6.72845983465
# Consumer Durables count: 4367

# %%
for industry in ma_deals['Target Industry Sector'].unique():
    actionids = ma_deals[ma_deals['Target Industry Sector'] == industry]['Action ID']
    print industry
    axis = [-2, 2, -5, 5]
    draw_relationship(actionids, ma_deals, actionid_eps_dict, ticker_price_dict, axis=axis)
    print

# %%
for industry in nasdaq_res['Target Industry Sector'].unique():
    subset_deals = nasdaq_res[nasdaq_res['Target Industry Sector'] == industry]
    print industry + ',' + str(subset_deals[['Est EPS diff', 'Return Used']].corr(method='spearman')['Return Used'][0])
# Out:
# Finance,0.348193261365
# Consumer Services,0.298804501922
# Technology,0.264140968575
# Public Utilities,0.221316966787
# Capital Goods,0.40695113696
# Basic Industries,0.311853053921
# Health Care,0.170750309862
# Energy,0.189915400083
# Miscellaneous,0.278165327395
# Transportation,0.261078355491
# n/a,0.202246348927
# Consumer Non-Durables,0.407606550176
# Consumer Durables,0.389989402877

# %%
nasdaq_res_df.sort_values('avg_abs_return').plot(x='Industry', y='avg_abs_return', kind='bar', rot =80)
plt.show()

nasdaq_res_df.sort_values('mean_return').plot(x='Industry', y='mean_return', kind='bar', rot =80)
plt.show()

nasdaq_res_df.sort_values('std_return').plot(x='Industry', y='std_return', kind='bar', rot =80)
plt.show()

nasdaq_res_df
# Out:
#                  Industry  avg_abs_return   max_return  mean_return  \
# 0                     All        5.693967  8354.545455     0.244547
# 1                 Finance        3.032407   162.411348     0.453140
# 2       Consumer Services        5.699374   723.170732     0.156477
# 3              Technology        6.767860   449.822064     0.039429
# 4        Public Utilities        5.383776    83.739837    -0.353694
# 5           Capital Goods        6.400430   145.547074     0.346210
# 6        Basic Industries        6.219960   264.946536    -0.167023
# 7             Health Care        6.600137  8354.545455     0.368286
# 8                  Energy        5.360209   342.934783    -0.005497
# 9           Miscellaneous        7.590888   627.272727     0.592784
# 10         Transportation        6.619069  1063.934426     1.178788
# 11                    n/a        3.130282    48.453608    -0.333985
# 12  Consumer Non-Durables        5.853684   161.297264     0.052224
# 13      Consumer Durables        6.728460    81.415929    -0.003030
#
#     min_retun  std_return
# 0  -75.263158   35.580283
# 1  -75.263158    5.434235
# 2  -53.846154   12.177267
# 3  -70.833333   10.566070
# 4  -70.000000    8.848755
# 5  -64.028777    9.714897
# 6  -45.299145   11.145622
# 7  -65.000000   75.169893
# 8  -38.446970   12.568109
# 9  -70.606061   21.404540
# 10 -68.506998   32.470470
# 11 -33.829787    5.374687
# 12 -61.290323    9.420788
# 13 -47.826087   10.212503

# %% [markdown]
# # SP500

# %%
sp500_companylist = pd.read_csv(base_dir + 'sp500_companylist.csv', header=0)
sp500_companylist['Symbol'] = sp500_companylist['Symbol'] + ' US'
write_BDS_csv(base_dir + 'sp500_eps_hist.csv', sp500_companylist['Symbol'])

# %%
sp500_eps_pull_df = load_df(base_dir + 'sp500_eps_pull.csv', 
                                 ['Quarter', 'Date', 'Time', 'Unknown', 'EPS', 'Est EPS'],
                                format_date=True)
cal_eps_diff(sp500_eps_pull_df)
sp500_eps_dict = load_ticker_dict(sp500_eps_pull_df, 'Date', 'Quarter')
write_BHD_price_csv(base_dir + 'sp500_BHD_price.csv', sp500_companylist['Symbol'])

# %%
def add_vol(price_df, day=10):
    price_df['vol'] = price_df['t - t-1'].rolling(window=10,center=False).std()
    return price_df

sp500_price_pull = load_df(base_dir + 'sp500_BHD_price_pull.csv', ['Date', 'Price'])

lags = range(2,5)
for lag in lags:
    add_price_lag(sp500_price_pull, lag)
#     add_price_lag(amex_price_pull, lag, forward=forward)
sp500_price_pull = add_vol(sp500_price_pull)
sp500_ticker_price_dict = load_ticker_dict(sp500_price_pull, 'Price', 'Date')
sp500_ticker_price_dict = remove_last_n_rows(sp500_ticker_price_dict, lag, forward)

# %%
sp500_price_pull
# Out:
#               Date  Price  Price Return lag2   t+1 - t   t - t-1  t+1 - t-1  \
# 0           MMM US    NaN                NaN       NaN       NaN        NaN
# 1         1/4/2010  83.02                NaN -0.626355       NaN        NaN
# 2         1/5/2010  82.50           0.782944  1.418182 -0.626355   0.782944
# 3         1/6/2010  83.67           1.490909  0.071710  1.418182   1.490909
# 4         1/7/2010  83.73           0.776861  0.704646  0.071710   0.776861
# 5         1/8/2010  84.32           0.298579 -0.403226  0.704646   0.298579
# 6        1/11/2010  83.98          -0.320209  0.083353 -0.403226  -0.320209
# 7        1/12/2010  84.05          -0.238152 -0.321237  0.083353  -0.238152
# 8        1/13/2010  83.78          -0.654372 -0.334209 -0.321237  -0.654372
# 9        1/14/2010  83.50          -0.489377 -0.155689 -0.334209  -0.489377
# 10       1/15/2010  83.37           1.940120  2.099076 -0.155689   1.940120
# 11       1/19/2010  85.12           1.619288 -0.469925  2.099076   1.619288
# 12       1/20/2010  84.72          -2.843045 -2.384325 -0.469925  -2.843045
# 13       1/21/2010  82.70          -3.824363 -1.475212 -2.384325  -3.824363
# 14       1/22/2010  81.48          -1.051995  0.429553 -1.475212  -1.051995
# 15       1/25/2010  81.83           0.184094 -0.244409  0.429553   0.184094
# 16       1/26/2010  81.63           0.574361  0.820777 -0.244409   0.574361
# 17       1/27/2010  82.30          -1.078035 -1.883354  0.820777  -1.078035
# 18       1/28/2010  80.75          -2.199271 -0.321981 -1.883354  -2.199271
# 19       1/29/2010  80.49          -0.383901 -0.062120 -0.321981  -0.383901
# 20        2/1/2010  80.44          -0.074543 -0.012432 -0.062120  -0.074543
# 21        2/2/2010  80.43           1.317752  1.330349 -0.012432   1.317752
# 22        2/3/2010  81.50          -1.516847 -2.809816  1.330349  -1.516847
# 23        2/4/2010  79.21          -3.631902 -0.845853 -2.809816  -3.631902
# 24        2/5/2010  78.54          -2.120944 -1.285969 -0.845853  -2.120944
# 25        2/8/2010  77.53           0.229183  1.534890 -1.285969   0.229183
# 26        2/9/2010  78.72           1.405907 -0.127033  1.534890   1.405907
# 27       2/10/2010  78.62           1.969004  2.098703 -0.127033   1.969004
# 28       2/11/2010  80.27           0.712287 -1.357917  2.098703   0.712287
# 29       2/12/2010  79.18           0.249159  1.629199 -1.357917   0.249159
# ...            ...    ...                ...       ...       ...        ...
# 21              -1.529090          -2.362009  1.028206
# 22              -2.349869          -3.605620  1.190580
# 23              -4.871166          -3.411043  1.274783
# 24              -0.618609          -0.744855  1.231869
# 25               0.101859           2.202699  1.229159
# 26               3.534116           2.128208  1.393172
# 27               0.584350           2.223069  1.335448
# 28               2.353091           1.933350  1.448877
# 29              -0.161953           1.046468  1.506368
# ...                   ...                ...       ...
# 970283           6.435800           8.617963  0.764022
# 970284           7.630837           9.229082  0.878943
# 970285           8.060766           6.107580  1.676444
# 970286           1.693656           3.268459  1.768575
# 970287           1.193769           0.888048  1.720194
# 970288          -0.588151          -0.832018  1.865385
# 970289           0.993426           0.628196  1.813414
# 970290          -0.906344           0.561070  1.750111
# 970291           0.865801           0.461760  1.782165
# 970292           0.708809           1.851584  1.687395
# 970293           2.221254           2.772938  1.698502
# 970294           1.273247           1.502146  1.747481
# 970295           1.910371           2.499282  1.242625
# 970296           1.349240           0.937367  1.112608
# 970297           0.395536           0.706314  1.032905
# 970298           0.479211           0.831572  0.762682
# 970299           0.252242           0.042040  0.688110
# 970300           0.450260           0.759814  0.662838
# 970301           0.448871           1.402721  0.636063
# 970302           1.048365           1.062343  0.618886
# 970303           1.274688          -0.518280  0.478042
# 970304          -0.823907          -1.061304  0.466605
# 970305          -1.991977          -1.825979  0.393541
# 970306          -1.839557          -0.912863  0.740265
# 970307           0.872994           1.210926  0.741545
# 970308           1.453776           1.298518  0.716284
# 970309           1.127237           1.775398  0.767608
# 970310           0.823562                NaN  0.768486
# 970311                NaN                NaN  0.765649
# 970312                NaN                NaN  0.782540
#
# [970313 rows x 9 columns]

# %%
df = sp500_ticker_price_dict['MMM US']
df
# df[df['Date'] == '10/24/2017']
df.to_csv('test.csv', index=False)

# %%
sp500_tickers = sp500_companylist['Symbol']
sp500_tickers_df = sp500_tickers.to_frame()

for index, row in sp500_tickers_df.iterrows():
    ticker = row['Symbol']
    eps_df =  sp500_eps_dict[ticker]
    df = eps_df.merge(sp500_ticker_price_dict[ticker], on='Date', how='left')
    col_name = 'Price Return lag' + str(lag)
    sp500_tickers_df.loc[index, 'Mean ' + col_name] = df[col_name].mean()

sp500_tickers_df['Sector'] = sp500_companylist['Sector']
sp500_tickers_df
# Out:
#        Symbol  Mean Price Return lag4                  Sector
# 0      MMM US               -0.011221             Industrials
# 1      ABT US                0.125807             Health Care
# 2     ABBV US                1.574690             Health Care
# 3      ACN US                0.889082  Information Technology
# 4     ATVI US                1.925177  Information Technology
# 5      AYI US                2.429834             Industrials
# 6     ADBE US                1.017833  Information Technology
# 7      AMD US               -1.154373  Information Technology
# 8      AAP US                0.351356  Consumer Discretionary
# 9      AES US               -0.423173               Utilities
# 10     AET US                0.616144             Health Care
# 11     AMG US                0.402061              Financials
# 12     AFL US                0.725089              Financials
# 13       A US                0.112254             Health Care
# 14     APD US                0.496337               Materials
# 15    AKAM US                0.583515  Information Technology
# 16     ALK US                0.208469             Industrials
# 17     ALB US                1.391709               Materials
# 18     ARE US               -0.400060             Real Estate
# 19    ALXN US                2.259705             Health Care
# 20    ALGN US                4.912720             Health Care
# 21    ALLE US                0.838074             Industrials
# 22     AGN US                1.117337             Health Care
# 23     ADS US                1.238444  Information Technology
# 24     LNT US                0.082868               Utilities
# 25     ALL US                1.035872              Financials
# 26   GOOGL US                1.288786  Information Technology
# 27    GOOG US                1.889462  Information Technology
# 28      MO US               -0.119902        Consumer Staples
# 29    AMZN US                1.735379  Consumer Discretionary
# ..        ...                     ...                     ...
# 475   VIAB US                0.068418  Consumer Discretionary
# 476      V US                0.770080  Information Technology
# 477    VNO US               -0.703177             Real Estate
# 478    VMC US                0.833662               Materials
# 479    WMT US               -0.141390        Consumer Staples
# 480    WBA US               -0.097130        Consumer Staples
# 481    DIS US                0.448799  Consumer Discretionary
# 482     WM US                0.287659             Industrials
# 483    WAT US                0.752016             Health Care
# 484    WEC US               -0.590012               Utilities
# 485    WFC US                0.271099              Financials
# 486    HCN US               -0.918545             Real Estate
# 487    WDC US               -0.367528  Information Technology
# 488     WU US                0.136584  Information Technology
# 489    WRK US                0.366353               Materials
# 490     WY US               -0.934763             Real Estate
# 491    WHR US               -0.209027  Consumer Discretionary
# 492    WMB US               -0.206707                  Energy
# 493   WLTW US               -1.381919              Financials
# 494    WYN US                1.603636  Consumer Discretionary
# 495   WYNN US                1.267580  Consumer Discretionary
# 496    XEL US                0.140441               Utilities
# 497    XRX US               -2.077304  Information Technology
# 498   XLNX US                0.921272  Information Technology
# 499     XL US                0.004754              Financials
# 500    XYL US                0.733621             Industrials
# 501    YUM US               -0.484219  Consumer Discretionary
# 502    ZBH US               -0.411633             Health Care
# 503   ZION US                0.893486              Financials
# 504    ZTS US                1.255571             Health Care
#
# [505 rows x 3 columns]

# %%
sp500_res = exchange_eps_price_return_concat(sp500_tickers_df, sp500_eps_dict, sp500_ticker_price_dict)
earnings_surprise_count(sp500_res)
# Out:
# All EPS report count: 36133
# NaN EPS report count: 3753
# Available EPS count: 32380
# Positive EPS surprise count: 24670 (76.189006%)
# Negative EPS surprise count: 7710 (23.810994%)

# %%
temp_sp500_res = sp500_res[sp500_res['Est EPS diff percentage'].notnull()]
temp_sp500_res = temp_sp500_res[temp_sp500_res['Price'].notnull()]
temp_sp500_res = temp_sp500_res[temp_sp500_res['vol'].notnull()]
# len(temp_sp500_res[temp_sp500_res['Return Used'].isnull()])
temp_sp500_res.to_csv('temp_sp500_res.csv', index=False)

# %%
x_label = 'Est EPS diff percentage'
# y_label = 'Price Return lag4'
y_label = 'Return Used'
axis = [-10, 20, -50, 50]
plot(temp_sp500_res, lags, x_label, y_label, axis=axis)
print temp_sp500_res[[x_label, y_label]].corr(method='spearman')
# Out:
#                          Est EPS diff percentage  Return Used
# Est EPS diff percentage                  1.00000      0.28025
# Return Used                              0.28025      1.00000

# %%
import numpy as np
import math

def autolabel(rects, ax):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')
        
def display_vol(res, return_thres=0):
    buckets = []
    avg_bucket_vol = []
    avg_thre_vol = []
    print 'Avg SP500 10-day vol on EPS date: %f' % res['vol'].mean()
    increment = 0.2
    for b in np.arange(-4.9, 5.0, increment):
        df = temp_sp500_res[temp_sp500_res[x_label] > b]
        df = df[df[x_label] < b+increment]
        if not len(df):
            continue
        buckets.append((b + b+increment)/2)
        bucket_vol = df['vol'].mean()
        thre_vol = df[df['Return Used'].abs() > return_thres]['vol'].mean()
        avg_bucket_vol.append(bucket_vol)
        if math.isnan(thre_vol):
            thre_vol = 0
        avg_thre_vol.append(thre_vol)
#         print '[%f, %f]' % (b, b+increment)
#         print 'Num of data: %d   Avg vol of data: %f' % (len(df), bucket_vol)
#         print df['Return Used'].std()
#         print 'Avg vol above threshold %f: %f' % (return_thres, thre_vol)
#         print
    N = len(buckets)
    ind = np.arange(N)  # the x locations for the groups
    width = 0.5       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, avg_bucket_vol, width, color='r')#, yerr=men_std)
    rects2 = ax.bar(ind + width, avg_thre_vol, width, color='y')#, yerr=women_std)
    # add some text for labels, title and axes ticks
    ax.set_ylabel('10-day Vol')
#     ax.set_title('')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(buckets)

    ax.legend((rects1[0], rects2[0]), ('Avg Vol', 'Avg Vol above threshold'))
#     autolabel(rects1, ax)
#     autolabel(rects2, ax)
    plt.show()

        
display_vol(temp_sp500_res, return_thres=10)
# Out:
# Avg SP500 10-day vol on EPS date: 1.661623

# %%
x_label = 'Est EPS diff percentage'
y_label = 'vol'
axis = [-10, 20, -5, 30]
plot(temp_sp500_res, lags, x_label, y_label, axis=axis)

# %% [markdown]
# # AMEX

# %%
amex_companylist = pd.read_csv(base_dir + 'amex_companylist.csv', header=0)
amex_companylist['Symbol'] = amex_companylist['Symbol'] + ' US'
# amex_tickers = amex_companylist['Symbol'] + ' US'
write_BDS_csv(base_dir + 'amex_eps_hist.csv', amex_companylist['Symbol'])

# %%
amex_eps_pull_df = load_df(base_dir + 'amex_eps_pull.csv', 
                                 ['Quarter', 'Date', 'Time', 'Unknown', 'EPS', 'Est EPS'],
                                format_date=True)
cal_eps_diff(amex_eps_pull_df)
amex_eps_dict = load_ticker_dict(amex_eps_pull_df, 'Date', 'Quarter')
write_BHD_price_csv(base_dir + 'amex_BHD_price.csv', amex_companylist['Symbol'])

# %%
amex_price_pull = load_df(base_dir + 'amex_BHD_price_pull.csv', ['Date', 'Price'])
for lag in lags:
    add_price_lag(amex_price_pull, lag, forward=forward)
# add_price_lag(amex_price_pull, lag)
amex_ticker_price_dict = load_ticker_dict(amex_price_pull, 'Price', 'Date')
amex_ticker_price_dict = remove_last_n_rows(amex_ticker_price_dict, 4, 1)

# %%
amex_tickers = amex_companylist['Symbol']
amex_tickers_df = amex_tickers.to_frame()
for index, row in amex_tickers_df.iterrows():
    ticker = row['Symbol']
    eps_df =  amex_eps_dict[ticker]
    df = eps_df.merge(amex_ticker_price_dict[ticker], on='Date', how='left')
    col_name = 'Price Return lag' + str(lag)
    amex_tickers_df.loc[index, 'Mean ' + col_name] = df[col_name].mean()

amex_tickers_df['Sector'] = amex_companylist['Sector']
amex_tickers_df
# Out:
#                 Symbol  Mean Price Return lag4                 Sector
# 0              XXII US               -5.178021  Consumer Non-Durables
# 1               FAX US                     NaN                    n/a
# 2               IAF US                     NaN                    n/a
# 3                CH US                     NaN                    n/a
# 4    ABE            US                     NaN                    n/a
# 5               FCO US                     NaN                    n/a
# 6                IF US                     NaN                    n/a
# 7               ISL US                     NaN                    n/a
# 8               ACU US                1.083694          Capital Goods
# 9              ATNM US                4.571128            Health Care
# 10               AE US                1.104892                 Energy
# 11              ACY US                0.793609             Technology
# 12             AIRI US                0.567162          Capital Goods
# 13              AXU US               -1.386935       Basic Industries
# 14              ALO US               32.305446       Basic Industries
# 15              AAU US                0.329797       Basic Industries
# 16              APT US               -2.473389            Health Care
# 17             AAMC US               -1.367616                Finance
# 18              DIT US               -1.727193  Consumer Non-Durables
# 19              ALN US               -2.243410  Consumer Non-Durables
# 20              AMS US               -0.449248            Health Care
# 21             USAS US               -1.196287       Basic Industries
# 22             AMPE US                3.040212            Health Care
# 23             APHB US               -4.513988            Health Care
# 24            ARNC^ US                     NaN                    n/a
# 25              AKG US                0.155668       Basic Industries
# 26             AINC US                3.558634      Consumer Services
# 27           ASB.WS US                     NaN                    n/a
# 28              AST US                3.346233            Health Care
# 29              AUG US                0.354948       Basic Industries
# ..                 ...                     ...                    ...
# 328             GGO US                     NaN                    n/a
# 329           GGO^A US                     NaN                    n/a
# 330             TMP US                0.042972                Finance
# 331             TAT US               -2.209416                 Energy
# 332            TRXC US               -0.527501            Health Care
# 333             TMQ US               -0.087399       Basic Industries
# 334            TPHS US               -1.330388      Consumer Services
# 335             TRT US                3.421173             Technology
# 336             HTM US               15.672815       Public Utilities
# 337            UFAB US               -1.080987          Capital Goods
# 338            UAMY US                1.094106          Capital Goods
# 339             UUU US               -1.886331  Consumer Non-Durables
# 340             UQM US               -4.603653          Capital Goods
# 341             URG US                2.724551       Basic Industries
# 342             UEC US               -2.378053       Basic Industries
# 343             VII US               -1.313484      Consumer Durables
# 344             VHC US               -0.820532          Miscellaneous
# 345             VGZ US               -1.361065       Basic Industries
# 346            VNRX US                0.007078            Health Care
# 347            VISI US                0.088691             Technology
# 348             EAD US                     NaN                    n/a
# 349             ERC US                     NaN                    n/a
# 350             ERH US                     NaN                    n/a
# 351             WRN US                0.427779       Basic Industries
# 352             WYY US               -1.806603             Technology
# 353             WTT US                0.872496          Capital Goods
# 354            XTNT US               -6.460298            Health Care
# 355            YUMA US                0.080855                 Energy
# 356            ZDGE US               -7.763417             Technology
# 357             ZOM US               -5.218173            Health Care
#
# [358 rows x 3 columns]

# %%
amex_res = exchange_eps_price_return_concat(amex_tickers_df, amex_eps_dict, amex_ticker_price_dict)

y_label = 'Price Return lag4'
axis = [-5, 5, -20, 20]
plot(amex_res, lags, 'Est EPS diff', y_label, axis=axis)
plot(amex_res, lags, 'Est EPS diff', 'Return Used', axis=axis)
print amex_res[['Est EPS diff', 'Return Used']].corr(method='spearman')
for lag in lags:
    print amex_res[['Est EPS diff', 'Price Return lag' + str(lag)]].corr(method='spearman')
# Out:
#               Est EPS diff  Return Used
# Est EPS diff       1.00000      0.17769
# Return Used        0.17769      1.00000
#                    Est EPS diff  Price Return lag2
# Est EPS diff            1.00000            0.16663
# Price Return lag2       0.16663            1.00000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.153495
# Price Return lag3      0.153495           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.147499
# Price Return lag4      0.147499           1.000000

# %%
amex_res_df = display_hist(amex_res, industry=True)
# Out:
# count: 11783
# Return Used return
# Max: 1649.29840973, Min: -59.2592592593
# Mean: 0.308501848277, Std: 26.9856200505
# Avg Absolute Return 5.82627391193
# Return Used return
# Max: 37.4141161774, Min: -29.375
# Mean: -0.885773350997, Std: 7.96759635159
# Avg Absolute Return 5.6151279506
# Consumer Non-Durables count: 707
# Return Used return
# Max: 49.0243902439, Min: -36.7830188679
# Mean: -0.668983446797, Std: 7.9486337603
# Avg Absolute Return 5.18079785506
# Capital Goods count: 1175
# Return Used return
# Max: 705.5, Min: -59.2592592593
# Mean: 0.0759225084229, Std: 23.5233165866
# Avg Absolute Return 6.4110333735
# Health Care count: 1968
# Return Used return
# Max: 1649.29840973, Min: -41.0138248848
# Mean: 2.07142759022, Std: 61.5007253226
# Avg Absolute Return 7.43425516183
# Energy count: 1513
# Return Used return
# Max: 70.4545454545, Min: -34.668989547
# Mean: -0.25671607746, Std: 10.2400261597
# Avg Absolute Return 7.00216394506
# Technology count: 1072
# Return Used return
# Max: 53.4615384615, Min: -31.843575419
# Mean: -0.159347040101, Std: 7.18603074473
# Avg Absolute Return 4.76227314053
# Basic Industries count: 2209
# Return Used return
# Max: 65.6626506024, Min: -28.2142857143
# Mean: 0.569602233831, Std: 6.1602061026
# Avg Absolute Return 3.08889604516
# Finance count: 719
# Return Used return
# Max: 723.170731707, Min: -48.0
# Mean: 0.900914320653, Std: 30.0404524598
# Avg Absolute Return 6.30476897186
# Consumer Services count: 1423
# Return Used return
# Max: 515.151515152, Min: -27.0833333333
# Mean: 2.27846826746, Std: 35.8599067112
# Avg Absolute Return 6.97202339791
# Public Utilities count: 400
# Return Used return
# Max: 29.4117647059, Min: -32.9545454545
# Mean: 0.0828711374496, Std: 7.10833757303
# Avg Absolute Return 4.66246031321
# Miscellaneous count: 292
# Return Used return
# Max: 47.7162293489, Min: -15.4352941176
# Mean: 0.326878890052, Std: 8.23359762636
# Avg Absolute Return 5.31234113416
# Consumer Durables count: 239
# Return Used return
# Max: 58.3333333333, Min: -23.7749546279
# Mean: -0.987002971932, Std: 16.6780106887
# Avg Absolute Return 9.80122918262
# n/a count: 21
# Return Used return
# Max: 22.3214285714, Min: -11.0367892977
# Mean: 0.934245606423, Std: 7.72695466052
# Avg Absolute Return 5.80036133388
# Transportation count: 45

# %%
amex_res_df.sort_values('avg_abs_return').plot(x='Industry', y='avg_abs_return', kind='bar', rot =80)
plt.show()

amex_res_df.sort_values('mean_return').plot(x='Industry', y='mean_return', kind='bar', rot =80)
plt.show()

amex_res_df.sort_values('std_return').plot(x='Industry', y='std_return', kind='bar', rot =80)
plt.show()

amex_res_df
# Out:
#                  Industry  avg_abs_return   max_return  mean_return  \
# 0                     All        5.826274  1649.298410     0.308502
# 1   Consumer Non-Durables        5.615128    37.414116    -0.885773
# 2           Capital Goods        5.180798    49.024390    -0.668983
# 3             Health Care        6.411033   705.500000     0.075923
# 4                  Energy        7.434255  1649.298410     2.071428
# 5              Technology        7.002164    70.454545    -0.256716
# 6        Basic Industries        4.762273    53.461538    -0.159347
# 7                 Finance        3.088896    65.662651     0.569602
# 8       Consumer Services        6.304769   723.170732     0.900914
# 9        Public Utilities        6.972023   515.151515     2.278468
# 10          Miscellaneous        4.662460    29.411765     0.082871
# 11      Consumer Durables        5.312341    47.716229     0.326879
# 12                    n/a        9.801229    58.333333    -0.987003
# 13         Transportation        5.800361    22.321429     0.934246
#
#     min_retun  std_return
# 0  -59.259259   26.985620
# 1  -29.375000    7.967596
# 2  -36.783019    7.948634
# 3  -59.259259   23.523317
# 4  -41.013825   61.500725
# 5  -34.668990   10.240026
# 6  -31.843575    7.186031
# 7  -28.214286    6.160206
# 8  -48.000000   30.040452
# 9  -27.083333   35.859907
# 10 -32.954545    7.108338
# 11 -15.435294    8.233598
# 12 -23.774955   16.678011
# 13 -11.036789    7.726955

# %% [markdown]
# # 20 deals from MA

# %%
def get_subset_from_deals(deals, subset_id, filename=None):
    subset_deals = deals.loc[deals['Action ID'].isin(subset_id)]
    if filename:
        subset_deals.to_csv(filename, index=False)
    return subset_deals

def eps_price_return_concat(deals, actionid_eps_dict, ticker_price_dict):
    concat_eps_return_list = []
    for index, row in deals.iterrows():
        actionid = row['Action ID']
        target_ticker = row['Target Ticker']
        if str(target_ticker) != 'nan':  # 4 tickers are nan in our MA deals
            eps_df = actionid_eps_dict[actionid]
            df = eps_df.merge(ticker_price_dict[target_ticker], on='Date', how='left')
            df['Action ID'] = actionid
            df['Target Ticker'] = target_ticker
#             if len(df):  # the names that have no eps available will not be shown
#                 print target_ticker
            if len(df):
                df['Return Used'] = [row[choose_return(row['Time'])] for index, row in df.iterrows()]
                concat_eps_return_list.append(df)
    return pd.concat(concat_eps_return_list)

def draw_relationship(actionids, deals, actionid_eps_dict, ticker_price_dict, axis=None, filename=None):
    subset_deals = get_subset_from_deals(deals, actionids, filename=filename)
    res = eps_price_return_concat(subset_deals, actionid_eps_dict, ticker_price_dict)
#     y_label = 'Price Return lag4'
    x_label = 'Est EPS diff'
    x1_label = 'Est EPS diff percentage'
    y_label = 'Return Used'
    plot(res, lags, x_label, y_label, axis=axis, marks='b.')
    plot(res, lags, x1_label, y_label, axis=axis, marks='r.')
#     plot(res, lags, x_label, 'Return Used', axis=axis)

    print res[[x_label, 'Return Used']].corr(method='spearman')
    for lag in lags:
        print res[[x_label, 'Price Return lag' + str(lag)]].corr(method='spearman')
# Out:
# US holiday 2017-11-10T00:00:00.000000000 Fri
# US holiday 2016-11-11T00:00:00.000000000 Fri
# US holiday 2013-01-21T00:00:00.000000000 Mon
# US holiday 2015-07-03T00:00:00.000000000 Fri
# US holiday 2016-11-11T00:00:00.000000000 Fri
# US holiday 2015-11-11T00:00:00.000000000 Wed
# weekend 2012-12-22T00:00:00.000000000 Sat
# US holiday 2013-02-18T00:00:00.000000000 Mon
# weekend 2012-11-11T00:00:00.000000000 Sun
# US holiday 2014-02-17T00:00:00.000000000 Mon
# weekend 2016-07-30T00:00:00.000000000 Sat
# US holiday 2010-11-11T00:00:00.000000000 Thur
# weekend 2016-01-24T00:00:00.000000000 Sun
# US holiday 2010-11-25T00:00:00.000000000 Thur
# US holiday 2013-11-11T00:00:00.000000000 Mon
# US holiday 2011-09-05T00:00:00.000000000 Mon
# weekend 2017-07-29T00:00:00.000000000 Sat
# US holiday 2017-05-29T00:00:00.000000000 Mon
# US holiday 2015-11-26T00:00:00.000000000 Thur
# US holiday 2016-02-15T00:00:00.000000000 Mon
# weekend 2012-08-05T00:00:00.000000000 Sun
# US holiday 2013-11-28T00:00:00.000000000 Thur
# US holiday 2015-11-26T00:00:00.000000000 Thur
# weekend 2016-02-28T00:00:00.000000000 Sun
# US holiday 2010-11-11T00:00:00.000000000 Thur
# weekend 2011-02-26T00:00:00.000000000 Sat
# US holiday 2015-01-19T00:00:00.000000000 Mon
# weekend 2017-05-28T00:00:00.000000000 Sun
# US holiday 2017-02-20T00:00:00.000000000 Mon
# weekend 2016-08-21T00:00:00.000000000 Sun
# weekend 2016-11-12T00:00:00.000000000 Sat
# US holiday 2017-11-10T00:00:00.000000000 Fri
# 32

# %%
tech_twenty_deals_actionid = [113811828,
134117432,
128891212,
73727936,
104686114,
75368792,
57058310,
129491390,
95714499,
76787058,
53392170,
111344916,
85028440,
134278416,
45271062,
105147132,
115060204,
54217001,
92585590,
65982151,
]

draw_relationship(tech_twenty_deals_actionid, ma_deals, actionid_eps_dict, ticker_price_dict, filename='twenty_deals_tech.csv')
# Out:
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.527442
# Return Used       0.527442     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.298628
# Price Return lag2      0.298628           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.208232
# Price Return lag3      0.208232           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.183231
# Price Return lag4      0.183231           1.000000

# %%
for industry in ma_deals['Target Industry Sector'].unique():
    actionids = ma_deals[ma_deals['Target Industry Sector'] == industry]['Action ID']
    print industry
    axis = [-2, 2, -5, 5]
    draw_relationship(actionids, ma_deals, actionid_eps_dict, ticker_price_dict, axis=axis)
    print
# Out:
# Consumer, Non-cyclical
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.070744
# Return Used       0.070744     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.075759
# Price Return lag2      0.075759           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff            1.00000            0.06063
# Price Return lag3       0.06063            1.00000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.046015
# Price Return lag4      0.046015           1.000000
#
# Communications
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.141943
# Return Used       0.141943     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.039808
# Price Return lag2      0.039808           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.062184
# Price Return lag3      0.062184           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.046481
# Price Return lag4      0.046481           1.000000
#
# Energy
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.011672
# Return Used       0.011672     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000          -0.034332
# Price Return lag2     -0.034332           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000          -0.056851
# Price Return lag3     -0.056851           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000          -0.019774
# Price Return lag4     -0.019774           1.000000
#
# Basic Materials
#               Est EPS diff  Return Used
# Est EPS diff       1.00000      0.16364
# Return Used        0.16364      1.00000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.148084
# Price Return lag2      0.148084           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.140002
# Price Return lag3      0.140002           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.056144
# Price Return lag4      0.056144           1.000000
#
# Technology
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.310322
# Return Used       0.310322     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.157653
# Price Return lag2      0.157653           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.111125
# Price Return lag3      0.111125           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.108338
# Price Return lag4      0.108338           1.000000
#
# Diversified
#               Est EPS diff  Return Used
# Est EPS diff           1.0         -0.5
# Return Used           -0.5          1.0
#                    Est EPS diff  Price Return lag2
# Est EPS diff                1.0               -0.5
# Price Return lag2          -0.5                1.0
#                    Est EPS diff  Price Return lag3
# Est EPS diff                1.0                1.0
# Price Return lag3           1.0                1.0
#                    Est EPS diff  Price Return lag4
# Est EPS diff                1.0                1.0
# Price Return lag4           1.0                1.0
#
# Industrial
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.165568
# Return Used       0.165568     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.248813
# Price Return lag2      0.248813           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.238505
# Price Return lag3      0.238505           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.186277
# Price Return lag4      0.186277           1.000000
#
# Financial
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.207584
# Return Used       0.207584     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.162202
# Price Return lag2      0.162202           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.076132
# Price Return lag3      0.076132           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.069815
# Price Return lag4      0.069815           1.000000
#
# Consumer, Cyclical
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.159801
# Return Used       0.159801     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.185587
# Price Return lag2      0.185587           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.208672
# Price Return lag3      0.208672           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.172322
# Price Return lag4      0.172322           1.000000
#
# Utilities
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.057848
# Return Used       0.057848     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.160009
# Price Return lag2      0.160009           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.070354
# Price Return lag3      0.070354           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.044908
# Price Return lag4      0.044908           1.000000

# %%
# for industry in ma_deals['Target Industry Sector'].unique():
#     subset_deals = ma_deals[ma_deals['Target Industry Sector'] == industry]
#     subset_deals = subset_deals[subset_deals['Payment Type'] != 'Cash']
#     actionids = subset_deals['Action ID']
#     print industry
#     axis = [-2, 2, -5, 5]
#     draw_relationship(actionids, ma_deals, actionid_eps_dict, ticker_price_dict, axis=axis)
#     print

# %%
for payment_type in ma_deals['Payment Type'].unique():
    subset_deals = ma_deals[ma_deals['Payment Type'] == payment_type]
    actionids = subset_deals['Action ID']
    print payment_type
    axis = [-2, 2, -5, 5]
    draw_relationship(actionids, ma_deals, actionid_eps_dict, ticker_price_dict, axis=axis)
    print
# Out:
# Stock
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.195391
# Return Used       0.195391     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.177546
# Price Return lag2      0.177546           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.162589
# Price Return lag3      0.162589           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.098354
# Price Return lag4      0.098354           1.000000
#
# Cash
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.112991
# Return Used       0.112991     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff             1.0000             0.0963
# Price Return lag2        0.0963             1.0000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.074512
# Price Return lag3      0.074512           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.073842
# Price Return lag4      0.073842           1.000000
#
# Cash and Stock
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.178085
# Return Used       0.178085     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.136209
# Price Return lag2      0.136209           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000           0.095255
# Price Return lag3      0.095255           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000           0.095807
# Price Return lag4      0.095807           1.000000
#
# Cash or Stock
#               Est EPS diff  Return Used
# Est EPS diff      1.000000     0.095706
# Return Used       0.095706     1.000000
#                    Est EPS diff  Price Return lag2
# Est EPS diff           1.000000           0.033928
# Price Return lag2      0.033928           1.000000
#                    Est EPS diff  Price Return lag3
# Est EPS diff           1.000000          -0.026206
# Price Return lag3     -0.026206           1.000000
#                    Est EPS diff  Price Return lag4
# Est EPS diff           1.000000          -0.003768
# Price Return lag4     -0.003768           1.000000
